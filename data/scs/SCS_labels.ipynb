# %% [markdown]
# ## Spoken Conversational Search Dataset Analysis

# %%
data_path = "/home/shared/cm_data/SCSdataset.csv"

import pandas as pd
df = pd.read_csv(data_path)
print(df.head(5))

# set up connection to the MongoDB: sudo service mongod start (27017 is the default port)

from pymongo import MongoClient
import json

class Mongo_Connector():
    '''
    Wrapper class for some of the pymongo functions: http://api.mongodb.com/python/current/tutorial.html
    '''

    def __init__(self, db_name):
        # spin up database
        self.mongo_client = MongoClient()
        self.db = self.mongo_client[db_name]
    
    def count_all_docs(self, collection_name):
        count = self.db[collection_name].count_documents({})
        print ("%d dialogues in %s" % (count, collection_name)) 

 
db_name = 'cm'
col_name = 'scs'
# connect to MongoDB
mongo = Mongo_Connector(db_name)
mongo.count_all_docs(col_name)
collection = mongo.db['scs']
# Out:
#   Start.time Stop.time                           Query Query.complexity  \
# 0    00:02.7   00:11.6  Where does cinnamon come from?         remember
# 1    00:40.9   00:51.9  Where does cinnamon come from?         remember
# 2    00:52.6   01:01.5  Where does cinnamon come from?         remember
# 3    01:02.3   01:11.8  Where does cinnamon come from?         remember
# 4    01:12.5   01:28.6  Where does cinnamon come from?         remember
#
#          Role                                             Action  \
# 0      A_User                      A:Initial information request
# 1  B_Receiver                        B:SERP without modification
# 2      A_User  A:Access source + Information request within d...
# 3  B_Receiver                    B:Within-Document search result
# 4      A_User  A:Access source + Information request within d...
#
#                                           Transcript  Query.counter  \
# 0  In which countries... in which European countr...              1
# 1  There's a bunch of results have come but first...              2
# 2  OK so in the top five in the second search res...              3
# 3  I'll just go in and have a look uhm no so we'v...              4
# 4  Can you just check in the Wikipedia, so open t...              5
#
#                                      File.name
# 0  2 - 1 June - 9.30am - Synchronized Clip.txt
# 1  2 - 1 June - 9.30am - Synchronized Clip.txt
# 2  2 - 1 June - 9.30am - Synchronized Clip.txt
# 3  2 - 1 June - 9.30am - Synchronized Clip.txt
# 4  2 - 1 June - 9.30am - Synchronized Clip.txt
# 37 dialogues in scs

# %%
# show all distinct actions
print("%d utterances" % len(df.Action))
complex_action_types = set(df.Action)
print("with %d distinct complex labels" % len(complex_action_types))
# print(action_types)

# encode labels
import string
alphabet = list(string.printable)
special_symbols = ['O', '<', '>']  # keep one symbol reserved for padding
alphabet = [x for x in alphabet if (x not in special_symbols) and x.isnumeric() == False]
print("Alphabet length: %d symbols"%len(alphabet))

labels2ids = {}
ids2labels = {'O': 'x', '<': 'START', '>': 'END'}
i = 0
for a in complex_action_types:
    for a_type in a[2:].split(' + '):
        if a_type not in labels2ids:
            labels2ids[a_type] = alphabet[i]
            ids2labels[alphabet[i]] = a_type
            i += 1
print("%d label types" % len(labels2ids))
# print(labels2ids.keys())
for k in alphabet:
    if k in ids2labels:
        print(k, ids2labels[k])
# Out:
# 1044 utterances
# with 135 distinct complex labels
# Alphabet length: 87 symbols
# 83 label types
# a Within SERP search result
# b Query rephrase
# c SERP overview without modification
# d SERP without modification
# e Scanning document with modification
# f Access source (implicit)
# g Access source feedback-request
# h Performance feedback
# i Recommendations
# j Automated repetitive search
# k Within-Document search result
# l Asking what they are looking for
# m Creating bigger picture
# n between-document navigation
# o Enquiry for further information
# p Requests more details about information request
# q SERP Card
# r Scanning document without modification BUT with interpretation of photos
# s Query refinement offer
# t Provides information about the search engine
# u Feedback on what is happening
# v Information request
# w Repeats the query back
# x Previously seen results
# y Scanning document without modification
# z Relevance judgement
# A Query embellishment
# B Results?
# C Google query expansion suggestion
# D Within-Document search result entity lookup request
# E Within-Document command response
# F Access search engine
# G Checks navigational command
# H Intent clarification
# I Information request within SERP
# J Definition lookup or Person
# K Info about document
# L Rejects
# M Interpretation
# N Information Request within Document
# P Multi-document summary
# Q Query repeat
# R Offers to spell
# S Comparing results against each other
# T Image overview on SERP
# U Read more from the document
# V Initial information request
# W Misheard
# X Repeats
# Y Enough information
# Z Info about SERP overview
# ! Wayfinding
# " SERP with modification
# # Asks to repeat
# $ Utter
# % Confirms
# & Information request within document
# ' Asking about usefulness
# ( Information Request
# ) Parahprasing from document which is not in front of them
# * Asks to repeat first search result
# + Requests spelling
# , Is there more information
# - Query formulation for info found in document
# . Information Request within SERP
# / Access source
# : Source information
# ; Informs user about searching for information found in document
# = Request to access Search engine
# ? Leave document
# @ Spells
# [ Asks to repeat Nth search result
# \ Suggestion to search more
# ] Interpretation biased towards information request or clarification given by the User
# ^ Definition explanation
# _ Asks if allowed to query embellish
# ` Within-document command
# { Requests "enough information" judgement
# | Interpretation of photos
# } Definition clarification
# ~ Next
#   Access link within document
# 	 Suggestion to move on

# %%
# 1. get traces of functional labels from MongoDB
cursor = collection.find({})

# interate over conversations to collect traces and utterance labels
traces = []
utterances = []
for doc in cursor:
    _id = doc['_id']
    # record trace as the sequence of labels
    labels_trace = '<'
    roles, sentiments = '<', '<'
    print(doc['query'])
    for turn in doc['turns']:
        labels = turn['labels']
        print(labels)
        print(turn['text'])
        for label in labels:
#             print(label)
            labels_trace += labels2ids[label]
            roles += turn['role'][0]
            sentiments += turn['sentiment']
            utterances.append(turn['role'][0]+labels2ids[label]+turn['sentiment'])
    # save in mongo
    fingerprint = {'labels': ''.join(labels_trace)+'>', 'roles': roles+'>', 'sentiments': sentiments+'>'}
    doc['traces'] = fingerprint
    doc['length'] = len(fingerprint['roles'])
    collection.update_one({'_id': _id}, {"$set": doc}, upsert=True)
    traces.append(fingerprint)
#     break
print("%d traces collected"%len(traces))
print("Sample trace: %s"%traces[17])
for key, value in traces[17].items():
    print(value)
# print("Sample trace: %s"%[ids2labels[label_id] for label_id in traces[15]])
print(utterances[0])
# Out:
# Where does cinnamon come from?
# ['Initial information request']
# In which countries... in which European countries do they grow cinnamon?
# ['SERP without modification']
# There's a bunch of results have come but first one is Wikipedia uhm which just talks about cinnamon but the next one talks about the top five uhm cinnamon producing countries
# ['Access source', 'Information request within document']
# OK so in the top five in the second search result is one of those top five countries a European country?
# ['Within-Document search result']
# I'll just go in and have a look uhm no so we've got Indonesia, China, Vietnam, Sri Lanka and Madagascar so I can back
# ['Access source', 'Information request within document']
# Can you just check in the Wikipedia, so open the Wikipedia page and maybe just scan uhm about where cinnamon is grown or where it has been migrated to
# ['Within-Document search result', 'Relevance judgement']
# Basically the definition of the word comes up and it says it is derivative from uhm Greek and French. The Greek borrowed it from oh my goodness, venus something rather word which is akin to hebrew uhm... the history... it doesn't, uhm, it says types of cinnamon are distinguished from Sri Lanka, North India, China uhm and then so the closest in, it's getting close to Europe uhm, the bark in Arab and Ethiopia, Egypt, Burma, Madagascar uhm... it talks about the Bible, different places, keep going, keep going, Middle Ages, Ethiopia, Marco Polo uhm OK so we're getting better. Uhm, still Sri Lanka though East Africa uhm, Phillipines, Mexico... cultivation, it talks about Madagascar, grading Sri Lanka species and different types of species, still no nothing European... yes I just don't think that there's
# ['Information request']
# OK can you just then type in uhm, the search phrase European cinnamon biscuits
# ['SERP without modification']
# OK the first thing that came up is European biscuit the gourmet merchant biscuits cookies then we've got Biscoff gourmet cookies and spread Europe's favourite cookie with with with something or rather uhm, buy gourmet cookies list of cookies Wikipedia European cookies, cinnamon sugar spice, cinnamon sugar spice that's what our classic Belgian biscuits are made off, European best biscuits cookies
# ['Access source']
# So if you uhm, look into one of the ones of the Belgian cookies or whichever country with cinnamon was it cinnamon sugar and spice?
# ['SERP without modification', 'Interpretation']
# Yeah ok, so I have LU european biscuits cinnamon sugar spice Wegmans and cinnamon sugar and spice that's what our classic Belgian biscuits are made of, we bake these richly flavoured cinnamon biscuits to be extra crisp with a special, so I think it is a type of biscuits so it is like Arnotts
# ['Access source', 'Information request within document']
# Does it does the on that site or piece of information does it say cinnamon that we get cinnamon from Sri Lanka or or does it tell me anything about cinnamon produce
# ['SERP without modification', 'Scanning document with modification']
# The first one talks about traditional Dutch cinnamon cookies but it doesn't talk about uhm, where cinnamon is actually coming from uhm, Biscoff, European coffee cinnamon and spices I a clicking I am just going in and having a look at some... so this one again is a it is a type of you know manufacturer this is Biscoff and it is, it's like you know as I said Arnotts, it talks about having to do with stuff like, but it doesn't actually
# ['Information request within document']
# Do you, does it have uhm, like a name for one of the biscuits like, you know we have Anzac biscuits and so forth does it say the name of a cinnamon biscuit the Belgian cinnamon biscuits or something
# Airport Security
# ['Initial information request']
# Can you type in uhm, effective effectiveness of new security measures at airports?
# ['Query refinement offer']
# Australia or is it just airports?
# ['Intent clarification']
# Put uhm international international airports
# ['SERP without modification', 'Interpretation']
# OK the first one that comes up is airport security measures aren't good enough here's a fix uhm it doesn't say who it's by looks like seems to be an article two thousand and fourteen so it is not that recent
# ['Info about document']
# Does it, is it from a newspaper or is it from a
# ['Source information', 'Interpretation']
# It is theconversation dot com so uhm, so it may be or may be a blog
# ['Confirms']
# OK
# ['SERP without modification', 'Interpretation']
# TSA guidelines for passengers on new security that's east Texas airpark, there's airport security Wikipedia, there's the debate over airport security uhm that seems to be from an organisation called the CFR uhm
# ['Access source']
# Can you just look at the CFR website
# ['Source information']
# This is a two thousand and ten so
# ['Rejects']
# OK try and yeah OK forget that one
# ['Confirms']
# OK
# ['Information request within SERP']
# What's the fourth article?
# ['Wayfinding']
# That was the fourth
# ['Next']
# What is the one next to
# ['SERP with modification', 'Interpretation']
# The next one is the impact of nine eleven so that's from two thousand and seven, so a lot of these tend to be quite old, two thousand and thirteen, two thousand and ten are you wanting anything newer?
# ['Information request']
# Ah uhm, new security measures after Brussels bombing
# ['Query refinement offer']
# OK effectiveness of new security measures at international airports... just add it
# ['Confirms']
# Yes yes
# ['SERP without modification']
# Okay so in Brussels airport bombing brings new security measures in the US that is two thousand and sixteen, so that's much better April nine uhm, we've got March two thousand and sixteen, Brussels attacks how airport bombings will change it is probably the air what security that's news dot com, Washington post was the first uhm article
# ['Access source']
# Can you just look at the news dot com
# ['Wayfinding', 'Scanning document without modification', 'Interpretation of photos']
# Yep that's the second one that's the Brussels attacks how airport bombings will change air [inaudible segment] [long pause] OK how attacks at Zaventem Zaventem airport in Brussels will change air travel uhm. It is just a picture of the, I think he is the mastermind uhm, it's, there's windows shattered at the airport and then Australian airports have consulted federal police following the shocking attacks on Brussels Airport uhm, it talks about that Australia's National University Counter-terrorism [inaudible segment]
# ['Information request within document']
# What are the countermeasures?
# ['Within-Document search result', 'Interpretation']
# Experts, he says most likely this week's arrest of Paris [inaudible segment] Obviously there is a ripple effect on aviation when an airport closes down airports will be looking at their own security it doesn't uhm... go into what you need, airlines were pointedly avoiding airspace over Brussels Australia's Department says they've changed the advice to travelling to a high degree of caution uhm [long pause] so there's a few airports that have screening before you get to the airport so it talks about Tokyo, Israel uhm, are two that spring to mind
# ['Information request']
# So uhm can you go and change the search question to effectiveness of uhm... passenger and baggage screenings at airport
# ['Asks to repeat']
# Passenger and
# ['Query repeat']
# Baggage
# ['Query refinement offer']
# So get rid of uhm, security measures
# ['Rejects']
# Uhm leave security measures
# ['Query refinement offer']
# And international, international airports brussels bombing, do we want to keep all of that?
# ['Intent clarification']
# No take out Brussels bombing
# ['SERP without modification']
# OK and we have Wikipedia airport security
# ['Access source']
# What does it say uhm just open Wikipedia
# ['Scanning document without modification']
# Airport security refers to techniques and methods
# ['Information request within document']
# Does it, is there any uhm sort of heading or subheading on uhm, effectiveness or
# ['Within-Document search result']
# Yeah, there is a description of of what is going on there's airport enforcement authorities like police and everyone who's blahbahblah process and equipment uhm, notable incidents, airport security by country and it just goes Canada Europe France Ireland no Iceland Netherlands Spain Sweden UK [inaudible segment] Israel Singapore
# ['Information request within document']
# What's it say on France for example?
# ['Scanning document without modification']
# France French security has been stepped up since terrorist attacks in France in nineteen eighty-six. That's a bit old. In response France established the Vigipirate program. The program uses troops to reinforce local security and increases requirements in screenings and ID checks. Since nineteen ninety-six security check-points have transferred from the Police Nationale uhm Gendarmerie to private companies hired by the airport authorities
# ['Information request']
# Okay uhm... oh god... can you just then type in uhm... improvements to
# ['Query refinement offer']
# So instead of effectiveness just improvements?
# ['Information request']
# Yeah well maybe start a new search improvements to uhm... passenger and baggage airport security
# ['Query refinement offer']
# OK is there a particular country that you're after?
# ['Intent clarification']
# Uhm just put Australia in just use that
# ['Asks to repeat']
# OK improvements to passenger and baggage security
# ['Intent clarification']
# Security screenings
# ['Query refinement offer']
# Security screenings... uhm get rid of international get rid of uhm... Australia
# ['Confirms']
# Yeah
# ['SERP without modification']
# Frequently asked questions security checks at airports uhm
# ['Access source']
# Okay go through go through that just see what the
# ['Source information']
# So this is uhm this is Australia government
# ['Confirms']
# OK
# ['Scanning document without modification']
# About infrastructure and this talks about general domestic screening procedures and general measures so the Australian passengers carry-on baggage uhm is very expensive, requiring screening for all flights could lead to some communities losing air services and it talks about highest security risk uhm
# ['Information request within document']
# Does it give you any numbers saying?
# ['Within-Document search result', 'Asking what they are looking for']
# Yeah so ninety-six percent of Australian domestic passengers in Australia depart from screened airports uhm... it doesn't give you any other statistics or numbers it then talks about cockpit doors training of police uhm reconciliation of passengers with their bags. I can go down and see if, is it statistics that you are looking for?
# ['Intent clarification', 'Information request within document']
# Yeah some measure whether it's maybe effective or not can you just then, if there is no statistics there like that are really visible
# ['Confirms']
# No no there isn't
# ['Information request']
# Can you just uhm type in how many people get caught at airport security checks
# ['Asks to repeat']
# How many people get caught at airport security checks yeah?
# ['Confirms']
# Yeah
# ['Previously seen results', 'SERP without modification', 'Interpretation biased towards information request or clarification given by the User']
# Uhm frequently asked questions we're back to that one again uhm, screening occurs people who carry weapons uhm [long pause] Ten things not to do in an airport... TSA two thousand and four uhm review TSA has been busy screening more than sixty five million, top ten airports for gun catches in two thousand fourteen, this TSA blog looks like it has some statistics
# ['Information request within SERP']
# Does it say x number of people or anywhere it says uhm
# ['Feedback on what is happening']
# It may I will need to go into it
# Outsource job India
# ['Initial information request']
# What US jobs have been outsourced to India
# ['Query refinement offer']
# Can I put uhm United States?
# ['Confirms']
# Yeah
# ['SERP without modification']
# [inaudible segment] Uhm job outsourcing to india benefits outsourcing services home this is from outsource2india dot com uhm... being situated on the other side of the globe from North America India has the advantage of blahblahblah. why outsource to India a recent survey eighty percent of Europe and US outsourcing firms ranked India as their number [inaudible segment] there is a how to [inaudible segment] outsourcing jobs uhm affects the US economy
# ['Access source']
# Uhm OK can you put bring up that
# ['Checks navigational command']
# This one? The outsourcing affects the US economy
# ['Confirms']
# Yeah
# ['Scanning document without modification']
# Yeah so how outsourcing jobs affects the US economy this is about money from a US economy expert
# ['Information request within document']
# Alright if you go if if you scan through that does it have any thing uhm classification of what type of jobs are outsourced or what industries are outsourced
# ['Scanning document without modification', 'Asks to repeat']
# There's a definition and then there's how it affects the economy and then it talks about Donald Trump uhm... call centre outsourcing human resources [inaudible segment] what was it again? What types of jobs
# ['Confirms']
# Yes, what industry, you mentioned telecommunications
# ['Scanning document without modification', 'Relevance judgement']
# So uhm here it talks about call centres outsourcing uhm... then it talks about human resources outsourcing uhm... there is a lot on health benefits conversation uhm [long pause] I don't see how some of these are relevant... is Mexico stealing US jobs
# ['Information request']
# Can you put in uhm type in top as in TOP industries outsourced to India or top USA industries outsourced to India
# ['Repeats the query back']
# So top USA industries outsourced to India
# ['Confirms']
# Hmm
# ['SERP without modification']
# Uhm which countries are more included to outsource versus shared... there are just a few major industries, huge political bodies, such as the US navy, NASA, the UK Inland Revenue so [inaudible segment] this this talks about
# ['Access source']
# Okay what's in it open that article or site
# ['Scanning document with modification']
# It's called horses for courses nah horses for sources, which industries are more inclined to outsource versus shared services, our recent state of, so it is research, they have done research that covers... home-truths about why organisations are more motivated to externalise their support operations to third-parties
# ['Rejects']
# Nah nah that's not what I want to find out
# ['Scanning document without modification', 'Asking what they are looking for']
# Here it has some statistics, industries going through change more focused on outsourcing than shared services, so here is what all different industries so entertainment, media, publishing, software and hi-tech, energy, chemicals, banking, finance. Is there one particular industry you're looking for?
# ['Intent clarification']
# Uhm just go in and look at uhm, no, no there's no industry I'm just looking for jobs but I'm trying to gage it, just say
# ['Scanning document with modification']
# So I can't go into any of these but what it does it has uhm a graph and it has outsourcing and shared services and it just gives you a percentage within those industries
# ['Information request within document']
# What's the industry with the highest percentage of outsourcing
# ['Within-Document search result']
# It is entertaini entertainment, media and publishing
# ['Information request']
# Can you put uhm, entertainment, media and publishing jobs comma USA outsourced to India
# ['Asks to repeat']
# What was it, media entertainment uhm... media entertainment publishing and publishing jobs... jobs outsourced to India. Does it have to be US media publishing?
# ['Query embellishment']
# Yes so put USA in somewhere
# ['SERP without modification', 'Interpretation']
# OK, major US media outlet outsourcing IT jobs to India this is the economictimes dot indiatimes dot com, major US media outlet outsourcing IT jobs to India it's published in two thousand sixteen so it's recent uhm then there is now outsourcing of media publishing work times of India that's back two thousand and four
# ['Access source']
# Can you just go in two thousand sixteen article
# ['Scanning document without modification']
# US media outlet outsourcing IT jobs to India this is a report uhm Washington major American company which owns prestigious uhm dailies like Los Angeles Times and Chicago Tribune will outsource a part of its IT component to Indian software
# ['Information request within document']
# Does it go, does it give you any numbers or statistics?
# ['Within-Document search result']
# Yeah it says BSE minus two point two nine percent, I don't know what that means though uhm and so there's a few other statistics with BSE thingymajig uhm and then it's got like related companies down a bit further TCS Tata consultants I think and that's got
# ['Definition lookup or Person']
# Can you look up somehow click on that page but also uhm maybe seperate window just to get a definition of BSE
# ['Within-Document search result', 'Interpretation']
# It says ET markets and it has markets news portfolio different little icon to click on it has Tata consultancy servicesLTD it looks like it is talking about market share so it's you know... got a graph
# ['Interpretation']
# Ah so BSE is a company is that what you are
# ['Within-Document search result', 'Interpretation']
# It may hmmm I don't know but it's it's it's got statistics like you know what you see with shares and it's got sell buy sell
# ['Interpretation']
# Oh OK yeah so BSE I think that minus two point nine was uhm the drop in share price or whatever
# ['Relevance judgement']
# So that is not what you are after and this tends to look like the whole page actually
# ['Confirms']
# Just let let's ignore that and uhm
# ['Checks navigational command']
# So go back?
# ['Confirms']
# Yeah
# ['SERP without modification']
# Uhm so if we go down a bit further US major media outlet outsourcing this is the deccanherald dot com major American company which owns prestigious
# recycle, automobile tires
# ['Initial information request']
# Uses for old car then the query or, passenger vehicle tyres TYRES or in caps tires TIRES... and I wanna uhm do a date range so the data is from the most recent twelve months, so uses for old car caps or passenger vehicle or tyres TYRES caps or tires TIRES and data in the last twelve months that's the query
# ['SERP without modification']
# So far from the last twelve months I first result is second hand tyres in Sydney uhm from a wreckers the second result is to compare tyres from drive dot com dot au uhm the third result is uhm another wreckers in Brisbane uhm used tyres in Frankston is the fourth result, wheel and rim profiles of passenger cars tyre size calculator uhm, then there is the car bible uhm wheel and tyre bible which looks like it is everything you need to know about wheels and tyres from car uhm the next one is Beaurepaires so an other tyres sales place uhm one used car pick the tyres uhm what damage does a car suffer if it's not regularly used on a forum and then the last result is Bridgestone pricing
# ['Query embellishment']
# So we need to change to something uhm... if we... uhm... let's say [long pause] if we change the search query to uhm... recycled and can we have that in uhm inverted commas so it say it must be in the uhm... in whatever is returned recycled and then car caps or passenger vehicle tire two different versions of tyres
# ['Asks to repeat']
# So uhm... where it's uses for old car tires uhm old car or passenger vehicle uhm where would you like recycled [inaudible segment]
# ['Query embellishment']
# So if we replace uhm uses for old, with the word recycled in inverted commas, thank you uhm so it would then be recycled car or passenger vehicle tyres tires and then at the end of this we have the word use
# ['Confirms']
# OK uhm
# ['Asks if allowed to query embellish']
# Actually can I add something else to that?
# ['Confirms']
# Yeah sure
# ['Query embellishment']
# Can we have not in caps wreckers and not sales actually just not wreckers first and let's see if we can use one of them
# ['SERP with modification']
# OK, with the not wreckers in the search we actually get a whole lot of wreckers yes... so the first five or six results all are for wreckers
# ['Query embellishment']
# Surely we should not be getting wreckers though we have not... uhm maybe just remove the word wreckers
# ['SERP without modification']
# Right now the first result is uhm has the heading committed to recycling used tyres Kmart Tyre and auto service, the second result is twelve amazing things you can make with recycled tyres from tyreright dot com dot au uhm, then the third one is a pintrest page, thirty amazing ideas to reuse and recycle old car tyres and the fourth result is also pintrest DIY car tyres on Pinterest old tyres, old cars and recycled tyres then there is a Youtube video how to make recycled scrap rubber and recycling ideas and then the next result Ecoflex International uhm, Ecoflex International is committed to the development of engineering products using recycled truck and car tyres uhm and then there is a website called the daily agenda and their subject line is wheels on their feet these catholic monks make shoes from old car tyres uhm then there is Timberland Tires uhm, when the tread wears out the tire lives in recycled, organic and renewable rubber and then there is wrenchapar dot com recycle a vehicle what happens to tires when car frames are recycled and then the last result on page one is more recycled car tyres reviews and profiles the Daily Monitor
# ['Asks to repeat first search result']
# So what was that last one?
# ['SERP with modification']
# Uhm more than just recycled car tyres it's from a website called the Monitor I don't think it's an Australian site uhm it's it sounds like it's a uhm article about a specific person using tools and cutters and hammers to make products out of recycled car tyres-
# ['Performance feedback', 'Asks to repeat first search result']
# That's not too bad we started to get a picture of some of the things it's used for uhm... what was you mentioned Timberland Tyres and then there was another one after that what was the one after Timberlands Tyres
# ['SERP without modification']
# Uhm recycling a vehicle what happens to the tyres when car frames are recycled
# ['Access source (implicit)']
# That would be one I would look at
# ['Checks navigational command']
# So do you want me to open that in a new tab?
# ['Confirms']
# Yes so open that page in a new tab
# ['Enquiry for further information']
# Is there anything else on that page?
# ['Asks to repeat first search result']
# What was the detail around Ecoflex International again?
# ['SERP without modification']
# Uhm so the short summary is Ecoflex International is committed to the development of engineering products using recycled truck and car tyres and then it goes as a means of achieving low-cost dotdotdot
# ['Performance feedback', 'Access source']
# I would be interested if I could open that in a new tab as well and Timberland Tyres in a new tab so that's three
# ['Scanning document with modification']
# So the first one is from wrench a part what happens to the tyres once the car frames are recycled uhm it's got a bunch of headings on this page uhm basically what happens when the tyres or the car frames recycled at so the junkyard sells them, recyclers sell them, recyclers recycle them, they reach landfill, and then the bottom one need to buy pre-owned tyres
# ['Access link within document']
# Uhm... could I open the recyclers recycle uhm in a new tab... if it allows that
# ['Feedback on what is happening']
# It doesn't seem to have... a... tab for that
# ['Information request within document']
# What information is available around recycling, recyclers recycling the tyres
# ['Within-Document search result']
# Some end-of-life vehicles are sold directly to recycle recyclers most of which specialise in recycling metal from cars and not rubber components such as tyres. Some recyclers require the tyres to be removed before they accept a vehicle. Recyclers that don't have this requirement often sell tyres to organisations that reuse them in original form or process them into a variety of new products. It looks like the majority of this website is based around uhm, buying and selling junk cars, so probably not so much on the recycling reuse of tyres... and it looks like it's based in the USA
# per capita alcohol consumption
# ['Initial information request']
# Please compare first word I'd like compare average international uhm and I'd like in inverted commas the words alcohol consumption... close inverted commas and then in open inverted commas per capita that's PER capita CAPITA close inverted commas... and that's if you could return the searches for that please
# ['Asks to repeat']
# Sorry what, can you repeat that sentence
# ['Query repeat']
# Compare average open inverted commas oh sorry compare average international open inverted commas alcohol consumption close inverted commas open inverted commas per capita close inverted commas
# ['SERP without modification']
# OK so the first result is Wikipedia and it's a list of countries by alcohol consumption per capita uhm and then the second source is also Wikipedia and that's uhm beer consumption per capita and then we have a pdf document from the World Health Organisation on global status report on alcohol and health uhm and we have a CNBC article uhm fifteen countries that consume the most alcohol uhm then it looks like an article from WSJ dot com which countries drink the most alcohol news dot com dot AU what countries drink the most amount of alcohol per capita and there is a website called statistica global per capita whiskey consumption uhm from two thousand and fourteen then a Wordpress site called epianalysis alcohol use around the globe new data trends and then the second to last one is US news dot com per capita USA and... yeah this one sort of seems to be very US focussed being high alcohol consumption in the US it sounds like a very US centric site and there is an other PDF from preventativehealth dot org dot AU key trends in alcohol consumption
# ['Access source']
# OK uhm... please open in a seperate tab the first one the Wikipedia alcohol consumption uhm per country per capita, the other one I would like open please is the last one you mentioned number 10 uhm the key trends in Australia in a seperate tab uhm and the fourth one you mentioned about uhm the fifteen countries that consume the most alcohol in a seperate tab, can we start with Wikipedia return response please?
# ['Scanning document with modification']
# OK so it looks like it's covering World Health Organisation data from two thousand and ten uhm and the report was published in two thousand and fourteen uhm it has calculations used by people aged fifteen years and older uhm... and unrecorded consumption was calculated using empirical investigations and judgements, the total sum is of reported and unreported consumption uhm and then there are columns in here that break up consumption by beer, wine, spirits and other uhm other refers to other alcoholic beverages such as rice wine, sake, kumi kumi, kwete, mead and cider, and then there's a two thousand fifteen projection attached to this
# ['Information request within document']
# Does the data uhm illustrate per capita consumption... by country?
# ['Within-Document search result']
# Uhm... I believe that that would be... the first column... OK this is the list of countries by alcohol consumption measured in equivalent litres of pure ethanol consumed per capita per year
# ['Performance feedback', 'Within-document command']
# Fantastic uhm please read out the top ten
# ['Within-Document search result']
# Uhm Belarus, Moldova, Lithuania, Russia, Romania, Ukraine, Andorra, Hungary, Czech Republic
# ['Information request within document']
# Where is Australia in the list?
# ['Within-Document search result']
# Number nineteen
# ['Information request within document']
# Number nineteen out of [inaudible segment]
# ['Within-Document search result']
# Hundred and ninety
# ['Creating bigger picture', 'between-document navigation']
# Nineteen out of a hundred and ninety, ten percent of rater's rate uhm OK thank you uhm, I would like to move to one of the other open tabs please
# ['SERP with modification']
# Yeah, so we have the PDF uhm and it is key trends in alcohol consumption uhm, it looks like it's part of a wider document uhm the document just got a heading with number two and two point one is alcohol consumption in Australia and other countries... there is a table on page two uhm which rates Australia as thirtieth and uhm consumption of alcohol consumption per capita out of a hundred and eighty countries and this is from a two thousand and eight World Health Organisation
# ['Access source (implicit)']
# With the other tab that is open, the Australian data
# ['Confirms']
# Ah yeah
# ['Information request within document']
# Does that page have a breakdown of per capita alcohol consumption by state?
# ['Within-Document search result', 'Query refinement offer']
# No... would you like me to search by state in Australia?
# ['Confirms']
# Yes please
# ['Query refinement offer']
# So I am searching compare average Australian state inverted commas alcohol consumption inverted commas per capita so I've just changed international
# ['Confirms']
# Thank you
# ['SERP without modification']
# Uhm so first result is that same Wikipedia by country, the second result is from Curtin University uhm and it is alcohol indicators executive summary uhm, and it's trends in alcohol-caused deaths and hospitalisation for all states and territories uhm, it does also seem in here uhm in the short summary it says the average Australian age fifteen and over consumed 9.32 litres pure ethanol in the financial year two thousand to two thousand and one so it may be very much in that date range, then the other one is from the Australian Bureau of Statistics and it is a two thousand thirteen two thousand fourteen and it is called apparent consumption of alcohol Australia uhm, and then the other one is from Bureau of Statistics Australian social trends nineteen ninety-five uhm and then we have another apparent consumption of alcohol Australia two thousand two two thousand thirteen from Bureau of Statistics uhm and then from MJA dot com dot AU per capita alcohol consumption in Australia will the real trend please stand up uhm and then Northern Territory tops statistics nationally for deaths from alcohol consumption that's an ABC article from two thousand fourteen uhm and then we've got how alcohol expenditure is distributed in Australia uhm, average alcohol expenditure in Australian states and territories uhm and then the fourth one is from AIHW dot gov dot AU and that looks from ninety-six ninety-seven results for uhm alcohol consumption in Australia I don't know if it gives you much in terms of state and then we've got another one from preventative health dot org dot AU uhm and it looks like table one shows Australia's level of per capita of alcohol consumption and it sort of has a lot of ellipsis and it doesn't give me a clear thing but it does point out that it has been cited by twelve other things on Google scholar
# What language do they speak in New Caledonia?
# ['Initial information request']
# Please search for the following phrase, what language, language in inverted commas is spoken in, open inverted commas New Caledonia close inverted commas, can you please check the Caledonia CALEDONIA
# ['SERP Card']
# Uhm it has come up straight away with a result uhm in Google uhm New Caledonia official language French
# Marine Vegetation
# ['Initial information request']
# Maybe just start of with type in marine vegetation and read up on what that kind of means
# ['Scanning document without modification']
# OK I have an article about marine vegetation plants that inhabit the seas and oceans, they include algae grasses mangrove trees and shrubs
# ['Information request within document']
# Yes so are there any algae does it say seaweed or kelp
# ['Within-Document search result']
# Uhm it says grasses, mangrove trees, shrubs, bacteria
# ['Confirms']
# Uhm yeah I think that should be fine just
# ['Scanning document without modification']
# OK, it says to a lesser degree fungi
# ['Asks to repeat']
# Sorry what
# ['Repeats']
# Fungi
# ['Confirms']
# Fungi ah yeah
# ['Scanning document without modification']
# Marine vegetation found in seas is algae which populates the pelagic zone to the lowest point of light penetration
# ['Confirms']
# Yeah OK uhm... yeah of course I think I have a pretty basic uhm sort of idea of what that is now uhm
# ['Confirms']
# OK
# ['Information request']
# Maybe then type in uhm use of marine vegetation as food or something like that, so something to do with it being food
# ['SERP without modification', 'Interpretation']
# Uhm I have this article the trapping and binding of subtidal carbonate sediments by marine vegetation in Bimini lagoon Bahamas... so it's a location
# ['Intent clarification']
# Yeah uhm so yeah how does that sort uhm related to that and source of food
# ['Confirms']
# OK, let me check
# ['Intent clarification']
# Yeah so I guess a good way to put it would be uhm can marine vegetation be a source of food food humans or something like that
# ['Requests more details about information request']
# Does it say something about mollusks? Squid? No, I don't think so
# ['Information request']
# Maybe type in marine vegetation and then in capitals do the and and type in food... and see what kind of searches you get from that
# ['SERP without modification']
# OK I have forests of the sea phytoplankton and marine plants
# ['Access source']
# Yeah maybe click on it and see see what it says so we can get a bit more information
# ['Scanning document with modification']
# It mainly describes about marine cellular organisms
# ['Asks to repeat']
# Sorry what was that
# ['Repeats']
# It mainly describes about marine uhm marine cellular organisms of the sea
# ['Information request within document']
# Does it say anything about it them being food?
# ['Within-Document search result']
# No it mainly says about the rocks and reefs
# ['Performance feedback']
# Uhm yeah I don't think that's really uhm too relevant
# ['Query refinement offer']
# Can is it the food for the humans or can
# ['Intent clarification']
# Uhm yeah it should yeah I think it relates to so marine vegetation is sort of yeah being food for humans to consume
# ['Scanning document without modification']
# Yeah it says fin fish, molluscs, and molluscs include octopus squids, seaweed, reptiles and marine mammals. The four the first four categories make up the bulk of the human food that comes from the waters of the world
# ['Information request within document']
# OK, so it's talking about food there?
# ['Confirms']
# Yeah
# ['Information request within document']
# Yeah uhm... does it say anything about... eating the benefits of eating those kind of things or
# ['Within-Document search result']
# No it's just a general description
# ['Confirms']
# Ah OK uhm
# ['SERP with modification']
# And I see some uhm links about the climate impacts on these habitats and uhm... organisms
# ['Asks to repeat']
# So what climate the effects of climate change on the
# ['Confirms']
# Yeah
# ['Rejects', 'Information request']
# Uhm that's not really that relevant for this uhm... maybe type in something like uhm the benefits of eating algae... see see what comes up... and maybe for the word benefits do an asterix on top of it so we get all the uhm words about similar to benefits
# ['SERP without modification']
# I have health benefits from eating fish and benefits of marine food and ingredients
# ['Asks to repeat']
# Marine food?
# ['Confirms']
# Yeah
# ['Access source']
# OK yeah maybe let's see what that's about
# ['Scanning document without modification']
# The health benefits of seafood consumption have primarily been associated with protective effects against cardiovascular diseases CVD
# ['Performance feedback', 'Recommendations']
# Yeah I think yeah that actually sounds pretty good that could potentially be relevant is there anything else or is that it?
# ['Scanning document without modification']
# Yeah there's more the health promoting effects have chiefly been attributed to the long-chain polyunsaturated fatty acids chemistry stuff
# ['Performance feedback', 'Information request']
# Yeah yeah that actually sounds pretty good uhm so maybe maybe just leave that [inaudible segment] and also conduct another search if that's cool... yeah so you ready now? Can you type in marine vegetation uhm and useful drug, as a drug or something to do with drugs
# ['Query refinement offer']
# So drugs from marine vegetation?
# ['Query embellishment']
# Yes so essentially uhm marine vegetation been able to be used as uhm a drug to cure illnesses
# ['Scanning document without modification']
# I have an article on marine natural products and their potential applications as anti-infective agents
# ['Access source', 'Information request within document']
# Yeah maybe have a look into that and do you think it would relate to uhm marine vegetation might help you or something like that when is used as a drug
# ['Scanning document without modification']
# Yeah marine marine natural products have successfully advanced to the late stages of clinical trails, including dolastatin ten it's chemistry [inaudible segment]
# Where does cinnamon come from?
# ['Initial information request']
# Maybe start of with uhm type in the origins of cinnamon
# ['SERP Card']
# Uhm I have around fifteen eighteen Portuguese traders discovered cinnamon at Ceylon present-day Sri Lanka
# ['Asks to repeat']
# Yes so yes are you saying that it's from Sri Lanka?
# ['Repeats']
# Yes it says fifteen eighteen from Sri Lanka
# ['Information request', 'Performance feedback']
# OK, yeah so yeah, the question I wanna ask is where does cinnamon sort of come from or where does it originate from so if it says it actually came from Sri Lanka or that's where it was first found so that's pretty helpful
# ['Scanning document with modification']
# Cinnamon is a spice obtained from the inner bark... mmm [long pause] so Wikipedia doesn't say anything about the origin
# ['Performance feedback', 'Information request']
# OK alright that's probably not relevant then so yeah we wanna just find something actually where does the spice cannanon cinnamon come from
# ['Scanning document without modification']
# I have something from history uhm... cinnamon has been in use by humans for thousands of years as early as two thousand BC Egyptians employed it
# ['Is there more information']
# Is that all that it says?
# ['Scanning document with modification']
# It doesn't say anything about the exact date
# ['Asks to repeat']
# So maybe it said when did it say uhm so two thousand BC or something?
# ['Confirms']
# Yes two thousand BC
# ['Information request']
# So maybe look that up with cinnamon because if it's been used for that long it was probably found around that time so see if we could find anything
# ['Scanning document without modification']
# So they initially used it as perfume in Egypt
# ['Is there more information']
# OK, is that all that it says?
# ['Feedback on what is happening']
# Nah, I'll just check that
# ['Confirms']
# Yeah
# ['SERP without modification']
# So I have an article that says the truth about where cinnamon comes from
# ['Asks to repeat']
# Where what comes from, sorry
# ['Confirms']
# Yeah
# ['Access source feedback-request']
# Have you clicked on it?
# ['Within-Document search result']
# Yeah yeah [long pause] But it doesn't give any information about the history
# ['Asks to repeat']
# So did you say it was used in Egypt before?
# ['Confirms']
# Yeah
# ['Information request']
# Can you type in cinnamon and Egypt... do capital and see to make sure we get uhm Egypt and potentially it might have originated there
# ['Scanning document without modification']
# There is one more article which says two thousand and eight hundred BC where it can be found referenced as kwai in Chinese writings
# ['Asks to repeat']
# So that was found in China, is that what you're saying or
# ['Repeats']
# It was referenced by the Chinese as kwai in Chinese writings
# ['Information request']
# OK so maybe type in China and cinnamon then and see what comes up
# ['Scanning document with modification']
# Yeah it mainly says Egyptians so
# ['Asks to repeat']
# Egyptians?
# ['Repeats', 'Multi-document summary']
# Egyptians, yeah I have two or three documents it says Egyptians two thousand BC
# ['Information request within document']
# That's when it was first used or first found?
# ['Within-Document search result']
# Used
# ['Requests "enough information" judgement']
# Uhm do you think that's enough to get an idea of where it actually came from or do you think we should keep going?
# ['Suggestion to search more']
# I think we should keep going
# ['Confirms']
# Yeah OK
# ['Query refinement offer']
# What sort of documents is it, when was it first used and not when it was first found? The actual place where it was first found
# ['Information request']
# Maybe type in again origin so origins and cinnamon and then and uhm Egypt
# ['Repeats the query back']
# So I have typed in cinnamon origin and Egypt
# ['Results?']
# Have you found anything
# ['Feedback on what is happening']
# No, I still keep on getting the same
# ['Asks to repeat']
# Same thing
# ['Confirms']
# Yeah same thing
# ['Information request within SERP']
# Is the word origin anywhere or no?
# ['Within SERP search result']
# No
# ['Information request']
# Maybe type in cinnamon discovered then and and discover or discovered do the asterix at the word discover
# ['SERP without modification']
# So I found one document which says where does cinnamon come from
# ['Access source']
# OK, definitely click on that, that could be useful
# ['Scanning document without modification']
# Yeah it's [inaudible segment] cinnamon which is native to Sri Lanka it says
# ['Asks to repeat']
# Native to?
# ['Repeats', 'Scanning document without modification']
# Sri Lanka from the bark of the cinnamon tree... that's not the biological name for the cinnamon
# ['Information request']
# OK maybe just to confirm that type in cinnamon Sri Lanka and see what comes up
# ['Scanning document without modification', 'Interpretation']
# The history of valuable cinnamon. The first mention of cinnamon is in Chinese documents dating from two thousand eight hundred BC. The ancient Egyptians logged cinnamon as a spice used in the embalming process... so it was first Chinese and then the Egyptians used it for some purpose
# ['Information request within document']
# That doesn't especially mean that it came from there does it
# ['Confirms']
# Yeah
# ['Confirms']
# Yeah
# ['Scanning document with modification']
# It mainly says about the history how cinnamon was used... but it... I don't see anything where it originated
# ['Information request']
# Maybe maybe just type in cinnamon uhm... into the search bar and just look at something really general because usually general things might
# ['Google query expansion suggestion']
# I have cinnamon origin
# ['Asks to repeat']
# What do you have sorry?
# ['SERP Card']
# So I have how the origin is Greek and then old French
# per capita alcohol consumption
# ['Initial information request']
# OK so... uhm in general I sort of want to try and find out the average consumption of alcohol uhm by by the country state for local level, so maybe just start of with type in uhm alcohol consumption by country... tell me if anything relates to statistics uhm about alcohol consumption uhm between countries
# ['SERP without modification']
# So I have one document about global consumption of alcohol by the World Bank
# ['Access source']
# Yeah do you want to click into it and see what it says
# ['SERP without modification']
# One sec [long pause] so I have list of countries by alcohol consumption per capita
# ['Performance feedback']
# Yeah yeah that's perfect
# ['Scanning document without modification']
# This is by Wikipedia [long pause] so this is uhm by twenty ten World Health Organisation... the data uhm the first one is Belarus the first country
# ['Information request within document']
# How much do they consume?
# ['Within-Document search result']
# It's fourteen point four litres per capita
# ['Confirms']
# OK
# ['Requests more details about information request']
# Are you looking for something specific or
# ['Intent clarification']
# Just sort of the yeah the alcohol consumption per countries per capita
# ['Confirms']
# OK
# ['Info about document']
# What website did you say we were on?
# ['Source information']
# Uhm... this is by Wikipedia
# ['Asks to repeat']
# Wikipedia?
# ['Confirms']
# Yeah
# ['Asks to repeat']
# OK uhm... can you maybe go on to, did you say that the statistics were from the World Health Organisation or something?
# ['Confirms']
# Yeah
# ['Information request within document']
# Is there a link somewhere to just verify because sometimes Wikipedia isn't always that reliable
# ['Confirms']
# OK let me check
# ['Information request within document']
# Like is there a footnote or anything
# ['Scanning document without modification']
# So I have one more website the world atlas, it says who drinks the most alcohol consumption by country
# ['Access source feedback-request']
# Have you clicked on it?
# ['Scanning document without modification']
# Yeah... and it says Estonia
# ['Interpretation']
# So it is different to Wikipedia
# ['Scanning document without modification']
# And that's the popular drink and [long pause] yeah it says Estonia's fourteen point nine seven
# ['Information request within document']
# Is this per capita?
# ['Within-Document search result']
# Yeah per capita
# ['Information request within document']
# When where these uhm statistics found or when were they released what date?
# ['Within-Document search result']
# So this was published January twenty-fifth twenty sixteen
# ['Performance feedback', 'Within-document command']
# Yeah so that is good then go go through that... so you got Estonia then
# ['Within-Document search result']
# Yeah and then the second one is Belarus
# ['Information request within document']
# Is Australia anywhere on the list?
# ['Within-Document search result']
# Uhm we are in the top ten
# ['Information request within document']
# So is there only top ten?
# ['Within-Document search result']
# No Australia is twenty-second
# ['Asks to repeat']
# Twenty-second
# ['Confirms']
# Yeah
# ['Information request within document']
# What's that per capita?
# ['Within-Document search result']
# Nine point eight seven
# ['Information request within document']
# How is that compared to the United States?
# ['Within-Document search result']
# No uhm it it's top twenty-five and and there's no US in the top rank
# ['Information request within document']
# Is there any other sort of Western countries on the top twenty-five similar to Australia for example Britain or New Zealand or something?
# ['Within-Document search result']
# We have Ireland, France... Ireland ranks seventh, France is eighth and Germany twelfth
# ['Information request']
# Yes so maybe maybe keep that up that yeah it's good you found that uhm and then type in alcohol per capita Australian states
# ['Query refinement offer']
# So this is it statewide, by state?
# ['Asks to repeat']
# Pardon by state or state wide you mean
# ['Query refinement offer']
# Australia
# ['Intent clarification']
# So pretty much what we're looking for is to compare alcohol consumption in the states in the Australian states... so Victoria compared to New South Wales
# ['Scanning document without modification']
# so the Australian Bureau of Statistics
# ['Performance feedback', 'Information request within document']
# Yeah that could be... that could be good, what's the article or what's the statistics about?
# ['Scanning document without modification']
# So in summary uhm... we have one eighty-three point seven million of pure alcohol in twenty thirteen to fourteen
# ['Is there more information']
# Is that all what it says or
# ['Scanning document with modification', 'Interpretation']
# Uhm it says based on the drinks and the year but it doesn't say anything about the state
# ['Leave document', 'Asks to repeat']
# Maybe you can get out of it then [long pause] so what's the search term that you typed in?
# ['Repeats the query back']
# It's alcohol per capita by state Australia
# ['Is there more information']
# OK uhm is there any other useful things to view?
# ...
# ['Information request within SERP']
# Yeah [long pause] so most of them are about seaweeds or uhm is there any uhm vegetables and growing kind of vegetables like seaweed, algae, kelp
# ['Request to access Search engine']
# Uhm can I use the RMIT library function as well?
# ['Confirms']
# Ah yeah that's maybe
# ['Query refinement offer']
# So do so look at one seaweed first just kelp or just or all of them at once
# ['Intent clarification']
# Uhm maybe look at each individual
# ['SERP without modification', 'Query refinement offer']
# There is a qualitative and quantitative evaluation of seaweed diet on sheep uhm we're looking at human not animal
# ['Confirms']
# Uh hum
# ['SERP without modification']
# There's an article called seaweed and human health
# ['Performance feedback']
# So that looks as just oh yeah because searching for seaweeds and
# ['Scanning document without modification']
# Uhm it says it has an important role in modulating current disease, unique bioactive compounds, lots of different proteins lectins phycobolliproteins peptides and amino acids, polyphenois, polysaccharides... uhm benefits include antiviral, anticancer and anticoagulant properties as well as the ability to modulate our health and assist with obesity and diabetes
# ['Interpretation', 'Information Request within Document']
# Yeah so it can help with diabetes uhm cancer... does it say specifically what type of cancer it is or or in general all cancers
# ['Within-Document search result']
# It just says anticancer properties
# ['Confirms']
# OK thanks
# ['Scanning document without modification']
# I don't it assists by health factors for obesity and diabetes
# ['Performance feedback']
# Yeah, that good
# ['Suggestion to move on']
# Shall we go onto a different uhm... uhm food like kelp?
# ['Confirms']
# Yeah
# ['SERP without modification']
# Ah we have an article on on plant extracts on the activity in plasma human blood plasma
# ['Information request within SERP']
# Plant extracts in terms of marine plants or
# ['Within-Document search result']
# Well specifically kelp well I hope... I will see what plants they're talking about exactly... extracts of kelp, fucus, yarrow, Saint John's wort, onion and honey
# ['Confirms']
# Hmmm
# ['Scanning document with modification']
# OK so this is mostly talking about... pollen and garlic powder not so much kelp
# ['Confirms']
# Yep
# ['Query refinement offer']
# I am finding a lot of a lot of kelp I will find more information about environmental impacts rather than... rather than the human effect on kelp
# ['Intent clarification']
# What type marine vegetation [long pause] is in general terms of these
# ['SERP without modification']
# I'm about we've got algae marine algae-derived bioactive peptides for human nutrition and health
# ['Confirms']
# Hmmm
# Cinnamon
# ['Initial information request']
# So I'm trying to find the count part in uhm a biscuits that you are get from Europe uhm it contains cinnamon and I want to know where the cinnamon is coming from are there is this uhm is this coming from Europe uhm so how to uhm search for uhm cinnamon Europe biscuits
# ['Asks to repeat']
# Cinnamon what sorry
# ['Query repeat']
# Europe
# ['Confirms']
# Europe
# ['Query embellishment']
# Cinnamon Europe biscuits... and uhm maybe origin
# ['SERP without modification']
# Uhm so we have a list of cookies on Wikipedia uhm a website with food timeline
# ['Information request within document']
# Yep... so what's the timeline is it about biscuits or
# ['Within-Document search result']
# Yeah there's a list of different biscuits
# ['Information request within document']
# Right, from Europe?
# ['Scanning document with modification', 'Query refinement offer']
# Uhm I think from a lot of places... it included there's a lot of different biscuits here, a bit of the history of them... are there any particular biscuits you're interested in?
# ['Intent clarification']
# Uhm that biscuit that contains cinnamon and spice uhm so has some cinnamon taste uhm not exactly what type of cinnamon that is from Europe so uhm what I'm trying to find where that cinnamon comes from
# ['Query refinement offer']
# Where the cinnamon is from?
# ['Intent clarification']
# Yeah so that biscuits that contains cinnamon and I'm trying to find where that cinnamon is from and it's uhm the biscuits are bought from Europe but the cinnamon is not from Europe
# ['Query rephrase']
# So it is a European biscuit
# ['Confirms']
# Yeah
# ['Query rephrase']
# That contains cinnamon
# ['Intent clarification']
# And the question is where that cinnamon is from the origin
# ['Query refinement offer']
# So we're looking for a particular brand?
# ['Intent clarification']
# Uhm I'm guessing it's looking for origin of that cinnamon so maybe it could be from China or Cuba or America
# ['Scanning document without modification']
# Uhm some biscuits are called speculoos speculoos chocolate olivers
# ['Information request within document']
# Does that contain cinnamon?
# ['Within-Document search result']
# Apparently yes it does butter and cinnamon are the main flavours... in uhm the speculoos
# ['Information request within document']
# Uhm does it mention is there a [inaudible segment]
# ['Asks to repeat']
# Pardon
# ['Information request within document']
# Uhm the cinnamon mentioned the cinnamon is the main flavour
# ['Within-Document search result']
# Yes, it says butter and cinnamon are the main flavour
# ['Confirms']
# Right
# ['Within-Document search result entity lookup request']
# Do you wanna look up that biscuit in particular?
# ['Confirms']
# Yeah
# ['SERP without modification']
# It's a spiced shortcrust biscuit
# ['Information request']
# Yeah so I'm trying to get uhm where that cinnamon originated from
# ['Scanning document without modification']
# Uhm it's a popular... this biscuit the speculoos biscuit which is a spiced biscuit mixed has cinnamon in it it's origin is Netherlands Belgium
# ['Information request within document']
# Uhm the origin of the biscuits or the origin of cinnamon
# ['Within-Document search result']
# The biscuits
# ['Confirms', 'Information Request']
# Ah OK uhm, is it possible to find the origin of the cinnamon inside the biscuits?
# ['Query refinement offer']
# Oh, I imagine cinnamon would be uhm origin would be different for each brand of biscuit uhm I can look up cinnamon origins if you'd like
# ['Confirms']
# Yeah
# ['SERP without modification']
# Portuguese traders discovered cinnamon at Ceylon... present-day Sri Lanka
# ['Information request within SERP']
# Uhm so that's for, that cinnamon is for that biscuits you mentioned?
# ['Multi-document summary']
# Cinnamon biscuits uhm... the issues is I believe cinnamon is grown around the world
# ['Confirms']
# Yeah
# ['Query refinement offer']
# Uhm, if you want me to find out informat manufacturer I can find out where the cinnamon from that biscuit comes from uhm
# ['Confirms']
# Yeah maybe that would be
# ['Query rephrase', 'SERP overview without modification']
# So I'm typing European biscuit manufactures [long pause] there's a company called Caobisco
# ['Confirms']
# Yeah
# ['SERP with modification']
# Uhm there's a company called Biscuitpeople and they they supply the ingredients and they're European I believe, oh, they're global but it includes Europe
# ['Information request']
# Yeah cause I that's everything that cinnamon is from Europe, so I was trying to look uhm is it from Europe or from other places
# ['Query refinement offer']
# I look up cinnamon suppliers... in Europe
# ['Query embellishment']
# Cinnamon suppliers to European biscuits manufacturer
# ['SERP with modification']
# Uhm Australia, traders suppliers that [long pause] this company is uhm there is... LU biscuits dot com cinnamon sugar spice shortbread [long pause] I have another one there is a list for there are biscuits cinnamon from Israel... and from Italy as well, more cinnamon biscuits here, so I'm on a bunch of different suppliers that sell different products, ALI is selling biscuit cinnamon
# ['Information request']
# Is it possible to know which area is the largest supplier?
# ['Within-Document search result']
# Western Europe sixty percent, Southern Europe twenty percent, Eastern Europe ten percent
# ['Information request within document']
# So they are all from Europe?
# ['Within-Document search result']
# Uhm it's from Italy but it's the market is in Europe
# ['Confirms']
# Hmm
# ['Query refinement offer']
# Uhm do you want some information about the cinnamon from that company?
# ['Rejects', 'Enough information']
# No I think I think that's enough
# ['Suggestion to move on']
# Ah, what else do we need?
# ['Enough information']
# I think that would be enough with that answer so it wasn't so
# ['Asks to repeat']
# Pardon
# ['Enough information', 'Interpretation']
# Uhm, I think I am good with that answer so most of that cinnamon comes from Europe
# ['Enquiry for further information']
# OK, so what do we do now?
# Alcohol consumption
# ['Initial information request']
# Can you start with alcohol consumption uhm in different countries
# ['SERP without modification', 'Enquiry for further information']
# I have scholar articles as well as I've got alcohol consumption per capita, would you like to see more of that?
# ['Confirms']
# Yeah yeah that's the one
# ['Scanning document with modification']
# Uhm I've got a list of every country and it comes with as well a breakdown of what type of alcohol it is
# ['Information request within document']
# Yeah uhm can you read out more about that does it start with something
# ['Within-Document search result', 'Requests more details about information request']
# Uhm yeah for every country there are a hundred is there a particular country you are interested in?
# ['Intent clarification']
# Uhm, all the countries all the states and all groups of people
# ['Scanning document without modification']
# Belarus has the highest consumption
# ['Utter']
# Well so they are saying
# ['Scanning document without modification']
# This is in two thousand and ten as well
# ['Confirms']
# Right
# ['Scanning document without modification']
# Uhm... this is in litres per capita seventeen point five litres per year uhm
# ['Information request within document']
# Is that average?
# ['Within-Document search result']
# I believe so I can go further into the actual uhm
# ['Information request within document']
# So it's a whole page talking about uhm the alcohol consumption
# ['Within-Document search result']
# Yeah it lists every country and the alcohol they consume
# Turkey watercontrol
# ['Initial information request']
# Search for rivers in Turkey and Iraq
# ['Asks to repeat']
# Rivers
# ['Query repeat']
# Rivers in Turkey and Iraq so that's RIVERS
# ['Query refinement offer']
# So do you want me to tell you names of rivers?
# ['Confirms']
# Uhm yes
# ['SERP without modification', 'Query refinement offer']
# So I'll look for uhm one is Euphrates, Great Zab, Khabur and Tigris so do you want me to, do you want more names of the rivers?
# ['Rejects', 'Information request']
# No that should be enough for the moment uhm... hmmm OK... so this is tricky uhm [long pause] alright it's Euphrates Euphrates uhm Turkey dam
# ['Enquiry for further information']
# Oh OK... yeah what do you want from that?
# ['Information request within SERP']
# And it needs to have uhm it needs to have all the are there any of those that have all the uhm the words?
# ['Repeats the query back', 'SERP without modification']
# Uhm you are looking for Euphrates Turkey dam... it's absolutely a dam
# ['Automated repetitive search']
# Yeah so there's there's one that has all that... OK uhm so you would uhm I'll I 'll note that down somewhere so that's one piece of information I want if you could go back one page to the list of uhm the list of rivers and if you could look and do the same search for the next rivers so whatever the name of the river is and Turkey and dam
# ['Query rephrase']
# So uhm so for all the four rivers you want the dam
# ['Automated repetitive search']
# Yeah, just one at the time so uhm you got Euphrates and then the second one was the ze
# ['Repeats']
# Great Zab
# ['Asks to repeat']
# Sorry
# ['Query refinement offer']
# Uhm is it the Tigris or the Great Zab?
# ['Automated repetitive search']
# Uhm either will do uhm I just need you to do the same search again Tigris dam Turkey
# ['Scanning document with modification', 'Enquiry for further information']
# Yeah sure [long pause] the dam is called uhm uhm do you want the name of this?
# ['Rejects']
# No that's fine
# ['Confirms']
# OK
# ['Information request']
# OK we just have a look at one of the dams so the one of the Euphrates, if you could ask when it was built
# ['Scanning document without modification']
# Uhm the construction began in nineteen eighty-three and was complete in nineteen ninety
# ['Information request']
# So nineteen ninety OK... alright so uhm we will then want to look at uhm water levels... Iraq
# ['Query rephrase']
# The water levels of the dam
# ['Intent clarification']
# Yes water levels Iraq Euphrates
# ['Query refinement offer']
# Uhm do you want the total capacity?
# ['Rejects', 'Information request']
# No I'm wanting a comparison between years so the years would be before say five years before nineteen ninety and five years afterwards... so for a period of time so it's then the Euphrates in Iraq
# ['Query rephrase']
# So you want the water level for
# ['Intent clarification']
# For the Euphrates in Iraq... uhm between nineteen eighty-five and nineteen ninety-five
# ['Asks to repeat']
# Nineteen ninety-five and
# ['Query repeat', 'Results?']
# Uhm nineteen eighty-five [long pause] were you able to find anything on the water levels in Iraq?
# ['Scanning document without modification']
# Previously it was I'm not sure but I think so it was thirty to ten power nine metre cube of volume
# ['Confirms']
# Hmmm
# ['Scanning document without modification']
# And then after the construction of the dam it raised to forty-eight point seven times ten to the power of nine metre cubed
# ['Performance feedback', 'Information request within document']
# OK that was something I wasn't expecting alright and that's in Iraq not Turkey
# ['Within-Document search result']
# It's the Turkey Syria border
# ['Information request']
# Right ah OK so that would be... OK is it possible to find is there anything on water resources in Iraq at all?
# ['Asks to repeat']
# Water resources
# River Rome
# ['Initial information request']
# The first search is rivers in Rome
# ['Query refinement offer']
# Yep do you want the names of the rivers?
# ['Intent clarification']
# No just just do a search on rivers in Rome
# ['SERP without modification']
# Yep so... I have the first thing I have is result is top ten rivers of Italy
# ['Next']
# OK uhm hmm yeah OK what's the next one?
# ['SERP with modification']
# So the second is for Tiber which is the name of the river which is the largest in Rome and the third is categories rivers of the province of Rome so uhm I think so it gives all the rivers in Rome and there is a list of the rivers in Italy
# ['Information request']
# Just put a question saying can you drink water from the tiger tiger
# ['Repeats']
# TIBER
# ['Confirms']
# Oh TIBER sorry Tiber yeah
# ['Feedback on what is happening']
# Yeah uhm just searching just one second
# ['Results?']
# Any luck?
# ['Scanning document with modification']
# No it's not drinkable it runs in the middle of the city
# ['Information request']
# Right OK, is Tiber the largest river in Rome?
# ['SERP with modification']
# No it's the third largest river in Italy
# ['Intent clarification']
# Yeah but in Rome itself?
# ['Asks to repeat']
# Can you tell me what you're asking for again?
# ['Query repeat']
# Is the Tiber the largest river in Rome?
# ['Scanning document with modification']
# No no
# ['Information request']
# So which one is the largest river in Rome?
# ['Scanning document without modification']
# Po river PO
# ['Information request', 'Enough information']
# The PO ah right right uhm can you drink the water from the Po [long pause] Actually I think we have enough information
# 37 traces collected
# Sample trace: {'labels': '<Vds%sHs%sHs%kd#X%"vsH#v#%bu%vs%deHk#ke%eMe%u$u%>', 'roles': '<ABBABABABABABBABABABABABABABABABBABABBABABABABA>', 'sentiments': '<OOOOOOOPOPOPOOOOOOOOOOOOPOOPOOPOOOOOOOPOOOPOOOP>'}
# <Vds%sHs%sHs%kd#X%"vsH#v#%bu%vs%deHk#ke%eMe%u$u%>
# <ABBABABABABABBABABABABABABABABABBABABBABABABABA>
# <OOOOOOOPOPOPOOOOOOOOOOOOPOOPOOPOOOOOOOPOOOPOOOP>
# AVO

# %%
# show a sampe dialogue
sample_doc = collection.find_one()
print(sample_doc['traces'])
# Out:
# {'labels': '<Vd/&k/&kzvd/dM/&de&>', 'roles': '<ABAABAABBABABBAABBA>', 'sentiments': '<OOOOOOOOOOOOOOOOOOO>'}

# %%
# show all traces
for doc in collection.find():
    print(doc['traces']['labels'][1:-1])
# Out:
# Vd/&k/&kzvd/dM/&de&
# VsHdMK:M%dM/:L%I!~"Mvs%d/!y|&kMv#QsLsHd/y&k&yvsvsH#Hs%d/:%y&klH&%v#%xd]Iu
# Vs%d/G%y&y#%yzvw%d/eLylHe&kv#AdM/y&kJkMMkMMz%G%d
# VdA#A%_%A"Ad*"h*dfG%o*dh/e u&k
# V#Qd/e&kh`k&k&kmn"f%&ks%s%d
# Vq
# Vy&k%y#X%y%%vdMH%Hpvd/e#X&khsHy&%&k%"#%Lvd#%/yhiyhvsAy/&y
# Vq#Xvhehvy,e#%vy,u%d#%gk#%vy#Xve#XP&k{\%svwBu#%Iavd/y#XyvyM&%%evC#q
# Vd/dhy&k%pH%K:#%#%&%&ygyMy&k&kh`k&k&k#%&k&k&kvs#sHyh&y,eM?#w,u#wAB%BuBe/wA
# V%B#Q"/G%.d%G%&%%
# VqIe&kvd'&k&k&k&k
# V%B"Ia%%Ia
# VsH}^sHId'/d'HsHd*X/y#X#%&kd/yhK:HsH
# V#Abqvd%yo#X&k
# VsHdsHdG%y,es%dsM(d/&G%z#zK:&e%eV#A#Ad'#%%d/G%y&eo&yo%y&k%(s%"p&pHug%*y&%Uy%(#QwA#Qwx%d~d/:%o%y
# Vd*dK:MM[dh/G&k&!%eM`EvqZqhq/G%yLG%(wdSvqo%qIa%
# Vq
# Vds%sHs%sHs%kd#X%"vsH#v#%bu%vs%deHk#ke%eMe%u$u%
# VqvqvsAbHyveMHy&d%
# Vb%s%PveMMevsHesHe
# V#QR%Qd%(y%yY
# VsHy&yMeh
# VT#T,y
# V"veve
# V"Hev"#HrvyMve-yM
# Ve#%He
# V#Q+@q#q
# VsACZ"He&ezMM%%eM
# V#As%Ce&#&yoHbAbQy&eM
# VsHsH%Bu%dvu%y%y%y%%v%ve;&u&eMvkM)%e
# V%Bd/sHy%y%y&#&k&y%y%y%y&#%kv%H#Ik%y%%K%%e%yv#%.k%e&y#%%y&#Hy%%&k%e&k
# V#Aq#"%%v#%dvd%d
# V#Qd%dHy%yFGtGv%%WH"I=%sHds%dhyMNk%yh	%dIk%e%sHd%
# V#Q%Ad&k&esHsHb%bHsHy&k&#&k%D%dvy&k%(s%dIP%s%bc%"vsA"vk&k%sLY	Y#YMo
# Vdo%e&kpHy$y%y&k&k
# V#Qs%dsLvoIwdjbjX#sjeoL%vyvbHsLvbH#QBy%yh&kv#
# VsHd~"vX%uBev"H#QevyvY

# %%
# show smallest traces
for doc in collection.find():
    if(doc['length'] < 15):
        for turn in doc['turns']:
#             _len += len(turn['labels'])
#             if _len > index and _len <= index + len(pattern):
            print(turn['labels'])
        print('\n')
# Out:
# ['Initial information request']
# ['SERP Card']
#
#
# ['Initial information request']
# ['Confirms']
# ['Results?']
# ['SERP with modification']
# ['Information request within SERP']
# ['Within SERP search result']
# ['Confirms']
# ['Confirms']
# ['Information request within SERP']
# ['Within SERP search result']
#
#
# ['Initial information request']
# ['SERP Card']
#
#
# ['Initial information request']
# ['Query refinement offer']
# ['Intent clarification']
# ['Scanning document without modification']
# ['Information request within document']
# ['Scanning document without modification']
# ['Interpretation']
# ['Scanning document with modification']
# ['Performance feedback']
#
#
# ['Initial information request']
# ['Image overview on SERP']
# ['Asks to repeat']
# ['Image overview on SERP']
# ['Is there more information']
# ['Scanning document without modification']
#
#
# ['Initial information request']
# ['SERP with modification']
# ['Information request']
# ['Scanning document with modification']
# ['Information request']
# ['Scanning document with modification']
#
#
# ['Initial information request']
# ['Scanning document with modification', 'Asks to repeat']
# ['Confirms', 'Intent clarification']
# ['Scanning document with modification']
#
#
# ['Initial information request']
# ['Asks to repeat']
# ['Query repeat']
# ['Requests spelling']
# ['Spells']
# ['SERP Card']
# ['Asks to repeat']
# ['SERP Card']

# %%
# what are the utterances per role?
u_by_roles = {}
for u in utterances:
    role = u[0]
    label = u[1]
    if role not in u_by_roles:
        u_by_roles[role] = defaultdict(int)
    u_by_roles[role][label] += 1

for role in u_by_roles:
    print("role %s utterances %d" % (role, sum(u_by_roles[role].values())))
    for label_id, count in positive_by_roles[role].items():
        print("label %s count %d" % (ids2labels[label_id], count))
    print('\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-bb6309ac896b> in <module>()
#       5     label = u[1]
#       6     if role not in u_by_roles:
# ----> 7         u_by_roles[role] = defaultdict(int)
#       8     u_by_roles[role][label] += 1
#       9
#
# NameError: name 'defaultdict' is not defined

# %%
# are there labels shared between different roles? Yes more than half
print(len(set(u_by_roles['A'].values())))
print(len(set(u_by_roles['B'].values())))
print(len(set(u_by_roles['A'].values()) & set(u_by_roles['B'].values()))/len(set(u_by_roles['B'].values())))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-117-af668454b230> in <module>()
#       1 # are there labels shared between different roles? Yes more than half
# ----> 2 print(len(set(u_by_roles['A'].values())))
#       3 print(len(set(u_by_roles['B'].values())))
#       4 print(len(set(u_by_roles['A'].values()) & set(u_by_roles['B'].values()))/len(set(u_by_roles['B'].values())))
#
# KeyError: 'A'

# %%
# which utterances have positive sentiment?
positive_utterances = []
from collections import defaultdict
positive_by_roles = {}
for u in utterances:
    if u[2] == 'P':
        role = u[0]
        label = u[1]
        if role not in positive_by_roles:
            positive_by_roles[role] = defaultdict(int)
        positive_by_roles[role][label] += 1
        # add unique type
        if u[:2] not in positive_utterances:
            positive_utterances.append(u[:2])
print("%d positive utterance types"%len(positive_utterances))
print(positive_utterances)
print(positive_by_roles)
# who (which role) is using more positive utterances
for role in positive_by_roles:
    print('\n')
    print("role %s positive %d" % (role, sum(positive_by_roles[role].values())))
    for label_id, count in positive_by_roles[role].items():
        print("label %s count %d" % (ids2labels[label_id], count))
# Out:
# 0 positive utterance types
# []
# {}

# %%
# find sample utterance by label
cursor = mongo.db.find()
for doc in cursor:
    for turn in doc['turns']:
        if 'P' in turn['sentiment']:
            print (turn['text'])
#             break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-119-0a6cbb6b20a2> in <module>()
#       1 # find sample utterance by label
# ----> 2 cursor = mongo.db.find()
#       3 for doc in cursor:
#       4     for turn in doc['turns']:
#       5         if 'P' in turn['sentiment']:
#
# /home/zola/anaconda3/envs/tf36/lib/python3.7/site-packages/pymongo/collection.py in __call__(self, *args, **kwargs)
#    3337                             "object it is failing because no such method "
#    3338                             "exists." %
# -> 3339                             self.__name)
#    3340         raise TypeError("'Collection' object is not callable. If you meant to "
#    3341                         "call the '%s' method on a 'Collection' object it is "
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'find' method on a 'Database' object it is failing because no such method exists.

# %%
# build a tree
# https://stackoverflow.com/questions/34964878/python-generate-a-dictionarytree-from-a-list-of-tuples/35049729

forest = []

for u in utterances:
    print(u)
    break
# Out:
# AzO

# %%
# 2. extract sequences frequent across multiple traces
# https://stackoverflow.com/questions/40556491/how-to-find-the-longest-common-substring-of-multiple-strings

from functools import partial, reduce
from itertools import chain
from typing import Iterator

from collections import Counter


def ngram(seq: str, n: int) -> Iterator[str]:
    return (seq[i: i+n] for i in range(0, len(seq)-n+1))


def allngram(seq: str, minn=1, maxn=None) -> Iterator[str]:
    lengths = range(minn, maxn) if maxn else range(minn, len(seq))
    ngrams = map(partial(ngram, seq), lengths)
    return set(chain.from_iterable(ngrams))


def frequent_ngrams(strings, min_support=None, topn=5, drop_substrings=False):
    
    # 1.split traces into ngrams
    seqs_ngrams = map(allngram, strings)

    # 2.count ngram frequencies
    counts = Counter(chain.from_iterable(seqs_ngrams))
    return counts.most_common(topn)

    # 3.filter frequent substrings
    # set frequency threshold if not specified
    if not min_support:
        most_frequent_s = [s for s, count in counts.most_common(topn)]
        # maximum frequency
#         most_frequent1 = counts.most_common(1)[0]
#         min_support = most_frequent1[1]
    else:
#         print(min_support)
        most_frequent={string: count for string, count in counts.items() if count >= min_support}
    #     print(most_frequent)
        most_frequent_s = list(most_frequent.keys())
    
    # 4.drop substrings
    if drop_substrings:
        most_frequent_s.sort(key=len, reverse=True)
        #     print(most_frequent_s)
        lfss = [most_frequent_s[0]]
        for s in most_frequent_s[1:]:
            overlap = False
            for lfs in lfss:
                if s in lfs:
                    overlap = True
                    break
            if not overlap:
                lfss.append(s)
    # result: longest frequent substrings with counts
    return lfss, [counts[s] for s in lfss]


# print(frequent_ngrams(traces, topn=50))
# print(len(traces))
labels_only = [trace['labels'] for trace in traces]
# print(labels_only[0])
patterns = frequent_ngrams(labels_only, min_support=2000, topn=100000000)
print(len(patterns))
for pattern in patterns:
    sequence, count = pattern
    # all starting patterns
    if sequence[0] == '<' or sequence[-1] == '>':
#     if len(sequence) > 4:
        print(pattern)
        labels = [ids2labels[label_id] for label_id in sequence]
        print(labels, count/37)
# Out:
# 28889
# ('<z', 37)
# ['START', 'Initial information request'] 1.0
# ('>', 37)
# ['END'] 1.0
# ('<', 37)
# ['START'] 1.0
# ('<zj', 9)
# ['START', 'Initial information request', 'Asks to repeat'] 0.24324324324324326
# ('<zG', 8)
# ['START', 'Initial information request', 'Query refinement offer'] 0.21621621621621623
# ('<zc', 6)
# ['START', 'Initial information request', 'SERP without modification'] 0.16216216216216217
# ('<zGN', 6)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification'] 0.16216216216216217
# ('<zjp', 6)
# ['START', 'Initial information request', 'Asks to repeat', 'Query repeat'] 0.16216216216216217
# ('b>', 5)
# ['Within-Document search result', 'END'] 0.13513513513513514
# ('ab>', 5)
# ['Information request within document', 'Within-Document search result', 'END'] 0.13513513513513514
# ('<zS', 5)
# ['START', 'Initial information request', 'SERP Card'] 0.13513513513513514
# ('7>', 5)
# ['Confirms', 'END'] 0.13513513513513514
# ('S>', 4)
# ['SERP Card', 'END'] 0.10810810810810811
# ('d>', 4)
# ['Scanning document with modification', 'END'] 0.10810810810810811
# ('<zGNc', 3)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification'] 0.08108108108108109
# ('c>', 3)
# ['SERP without modification', 'END'] 0.08108108108108109
# ('7c>', 3)
# ['Confirms', 'SERP without modification', 'END'] 0.08108108108108109
# ('f>', 3)
# ['Scanning document without modification', 'END'] 0.08108108108108109
# ('<z7', 3)
# ['START', 'Initial information request', 'Confirms'] 0.08108108108108109
# ('<z76', 3)
# ['START', 'Initial information request', 'Confirms', 'Results?'] 0.08108108108108109
# ('<zj5', 3)
# ['START', 'Initial information request', 'Asks to repeat', 'Query embellishment'] 0.08108108108108109
# ('3>', 3)
# ['Interpretation', 'END'] 0.08108108108108109
# ('<zcT', 2)
# ['START', 'Initial information request', 'SERP without modification', 'Access source'] 0.05405405405405406
# ('<zjpc', 2)
# ['START', 'Initial information request', 'Asks to repeat', 'Query repeat', 'SERP without modification'] 0.05405405405405406
# ('zS>', 2)
# ['Initial information request', 'SERP Card', 'END'] 0.05405405405405406
# ('jS>', 2)
# ['Asks to repeat', 'SERP Card', 'END'] 0.05405405405405406
# ('bab>', 2)
# ['Within-Document search result', 'Information request within document', 'Within-Document search result', 'END'] 0.05405405405405406
# ('abab>', 2)
# ['Information request within document', 'Within-Document search result', 'Information request within document', 'Within-Document search result', 'END'] 0.05405405405405406
# ('c7>', 2)
# ['SERP without modification', 'Confirms', 'END'] 0.05405405405405406
# ('Nd>', 2)
# ['Intent clarification', 'Scanning document with modification', 'END'] 0.05405405405405406
# ('2>', 2)
# ['Enough information', 'END'] 0.05405405405405406
# ('<z4', 2)
# ['START', 'Initial information request', 'SERP with modification'] 0.05405405405405406
# ('d3>', 2)
# ['Scanning document with modification', 'Interpretation', 'END'] 0.05405405405405406
# ('<zcTabTa', 1)
# ['START', 'Initial information request', 'SERP without modification', 'Access source', 'Information request within document', 'Within-Document search result', 'Access source', 'Information request within document'] 0.02702702702702703
# ('abgmcTc3Tacda>', 1)
# ['Information request within document', 'Within-Document search result', 'Relevance judgement', 'Information request', 'SERP without modification', 'Access source', 'SERP without modification', 'Interpretation', 'Access source', 'Information request within document', 'SERP without modification', 'Scanning document with modification', 'Information request within document', 'END'] 0.02702702702702703
# ('<zcTabTabgmcTc3Tacda', 1)
# ['START', 'Initial information request', 'SERP without modification', 'Access source', 'Information request within document', 'Within-Document search result', 'Access source', 'Information request within document', 'Within-Document search result', 'Relevance judgement', 'Information request', 'SERP without modification', 'Access source', 'SERP without modification', 'Interpretation', 'Access source', 'Information request within document', 'SERP without modification', 'Scanning document with modification', 'Information request within document'] 0.02702702702702703
# ('TabTabgmcTc3Tacda>', 1)
# ['Access source', 'Information request within document', 'Within-Document search result', 'Access source', 'Information request within document', 'Within-Document search result', 'Relevance judgement', 'Information request', 'SERP without modification', 'Access source', 'SERP without modification', 'Interpretation', 'Access source', 'Information request within document', 'SERP without modification', 'Scanning document with modification', 'Information request within document', 'END'] 0.02702702702702703
# ('<zcTabTabgm', 1)
# ['START', 'Initial information request', 'SERP without modification', 'Access source', 'Information request within document', 'Within-Document search result', 'Access source', 'Information request within document', 'Within-Document search result', 'Relevance judgement', 'Information request'] 0.02702702702702703
# ('cda>', 1)
# ['SERP without modification', 'Scanning document with modification', 'Information request within document', 'END'] 0.02702702702702703
# ('<zcTabTabgmcTc3Tacd', 1)
# ['START', 'Initial information request', 'SERP without modification', 'Access source', 'Information request within document', 'Within-Document search result', 'Access source', 'Information request within document', 'Within-Document search result', 'Relevance judgement', 'Information request', 'SERP without modification', 'Access source', 'SERP without modification', 'Interpretation', 'Access source', 'Information request within document', 'SERP without modification', 'Scanning document with modification'] 0.02702702702702703
# ('cTabTabgmcTc3Tacda>', 1)
# ['SERP without modification', 'Access source', 'Information request within document', 'Within-Document search result', 'Access source', 'Information request within document', 'Within-Document search result', 'Relevance judgement', 'Information request', 'SERP without modification', 'Access source', 'SERP without modification', 'Interpretation', 'Access source', 'Information request within document', 'SERP without modification', 'Scanning document with modification', 'Information request within document', 'END'] 0.02702702702702703
# ('<zcTabTabgmcTc3Tac', 1)
# ['START', 'Initial information request', 'SERP without modification', 'Access source', 'Information request within document', 'Within-Document search result', 'Access source', 'Information request within document', 'Within-Document search result', 'Relevance judgement', 'Information request', 'SERP without modification', 'Access source', 'SERP without modification', 'Interpretation', 'Access source', 'Information request within document', 'SERP without modification'] 0.02702702702702703
# ('<zcTabTabgmcTc', 1)
# ['START', 'Initial information request', 'SERP without modification', 'Access source', 'Information request within document', 'Within-Document search result', 'Access source', 'Information request within document', 'Within-Document search result', 'Relevance judgement', 'Information request', 'SERP without modification', 'Access source', 'SERP without modification'] 0.02702702702702703
# ('mcTc3Tacda>', 1)
# ['Information request', 'SERP without modification', 'Access source', 'SERP without modification', 'Interpretation', 'Access source', 'Information request within document', 'SERP without modification', 'Scanning document with modification', 'Information request within document', 'END'] 0.02702702702702703
# ('<zcTabT', 1)
# ['START', 'Initial information request', 'SERP without modification', 'Access source', 'Information request within document', 'Within-Document search result', 'Access source'] 0.02702702702702703
# ('gmcTc3Tacda>', 1)
# ['Relevance judgement', 'Information request', 'SERP without modification', 'Access source', 'SERP without modification', 'Interpretation', 'Access source', 'Information request within document', 'SERP without modification', 'Scanning document with modification', 'Information request within document', 'END'] 0.02702702702702703
# ('Tacda>', 1)
# ['Access source', 'Information request within document', 'SERP without modification', 'Scanning document with modification', 'Information request within document', 'END'] 0.02702702702702703
# ('c3Tacda>', 1)
# ['SERP without modification', 'Interpretation', 'Access source', 'Information request within document', 'SERP without modification', 'Scanning document with modification', 'Information request within document', 'END'] 0.02702702702702703
# ('a>', 1)
# ['Information request within document', 'END'] 0.02702702702702703
# ('<zcTabTabgmc', 1)
# ['START', 'Initial information request', 'SERP without modification', 'Access source', 'Information request within document', 'Within-Document search result', 'Access source', 'Information request within document', 'Within-Document search result', 'Relevance judgement', 'Information request', 'SERP without modification'] 0.02702702702702703
# ('<zcTabTabgmcTc3', 1)
# ['START', 'Initial information request', 'SERP without modification', 'Access source', 'Information request within document', 'Within-Document search result', 'Access source', 'Information request within document', 'Within-Document search result', 'Relevance judgement', 'Information request', 'SERP without modification', 'Access source', 'SERP without modification', 'Interpretation'] 0.02702702702702703
# ('Tc3Tacda>', 1)
# ['Access source', 'SERP without modification', 'Interpretation', 'Access source', 'Information request within document', 'SERP without modification', 'Scanning document with modification', 'Information request within document', 'END'] 0.02702702702702703
# ('bgmcTc3Tacda>', 1)
# ['Within-Document search result', 'Relevance judgement', 'Information request', 'SERP without modification', 'Access source', 'SERP without modification', 'Interpretation', 'Access source', 'Information request within document', 'SERP without modification', 'Scanning document with modification', 'Information request within document', 'END'] 0.02702702702702703
# ('da>', 1)
# ['Scanning document with modification', 'Information request within document', 'END'] 0.02702702702702703
# ('abTabgmcTc3Tacda>', 1)
# ['Information request within document', 'Within-Document search result', 'Access source', 'Information request within document', 'Within-Document search result', 'Relevance judgement', 'Information request', 'SERP without modification', 'Access source', 'SERP without modification', 'Interpretation', 'Access source', 'Information request within document', 'SERP without modification', 'Scanning document with modification', 'Information request within document', 'END'] 0.02702702702702703
# ('<zcTa', 1)
# ['START', 'Initial information request', 'SERP without modification', 'Access source', 'Information request within document'] 0.02702702702702703
# ('acda>', 1)
# ['Information request within document', 'SERP without modification', 'Scanning document with modification', 'Information request within document', 'END'] 0.02702702702702703
# ('<zcTabTabg', 1)
# ['START', 'Initial information request', 'SERP without modification', 'Access source', 'Information request within document', 'Within-Document search result', 'Access source', 'Information request within document', 'Within-Document search result', 'Relevance judgement'] 0.02702702702702703
# ('<zcTab', 1)
# ['START', 'Initial information request', 'SERP without modification', 'Access source', 'Information request within document', 'Within-Document search result'] 0.02702702702702703
# ('<zcTabTab', 1)
# ['START', 'Initial information request', 'SERP without modification', 'Access source', 'Information request within document', 'Within-Document search result', 'Access source', 'Information request within document', 'Within-Document search result'] 0.02702702702702703
# ('<zcTabTabgmcTc3Ta', 1)
# ['START', 'Initial information request', 'SERP without modification', 'Access source', 'Information request within document', 'Within-Document search result', 'Access source', 'Information request within document', 'Within-Document search result', 'Relevance judgement', 'Information request', 'SERP without modification', 'Access source', 'SERP without modification', 'Interpretation', 'Access source', 'Information request within document'] 0.02702702702702703
# ('cTc3Tacda>', 1)
# ['SERP without modification', 'Access source', 'SERP without modification', 'Interpretation', 'Access source', 'Information request within document', 'SERP without modification', 'Scanning document with modification', 'Information request within document', 'END'] 0.02702702702702703
# ('<zcTabTabgmcT', 1)
# ['START', 'Initial information request', 'SERP without modification', 'Access source', 'Information request within document', 'Within-Document search result', 'Access source', 'Information request within document', 'Within-Document search result', 'Relevance judgement', 'Information request', 'SERP without modification', 'Access source'] 0.02702702702702703
# ('3Tacda>', 1)
# ['Interpretation', 'Access source', 'Information request within document', 'SERP without modification', 'Scanning document with modification', 'Information request within document', 'END'] 0.02702702702702703
# ('TabgmcTc3Tacda>', 1)
# ['Access source', 'Information request within document', 'Within-Document search result', 'Relevance judgement', 'Information request', 'SERP without modification', 'Access source', 'SERP without modification', 'Interpretation', 'Access source', 'Information request within document', 'SERP without modification', 'Scanning document with modification', 'Information request within document', 'END'] 0.02702702702702703
# ('<zcTabTabgmcTc3T', 1)
# ['START', 'Initial information request', 'SERP without modification', 'Access source', 'Information request within document', 'Within-Document search result', 'Access source', 'Information request within document', 'Within-Document search result', 'Relevance judgement', 'Information request', 'SERP without modification', 'Access source', 'SERP without modification', 'Interpretation', 'Access source'] 0.02702702702702703
# ('zcTabTabgmcTc3Tacda>', 1)
# ['Initial information request', 'SERP without modification', 'Access source', 'Information request within document', 'Within-Document search result', 'Access source', 'Information request within document', 'Within-Document search result', 'Relevance judgement', 'Information request', 'SERP without modification', 'Access source', 'SERP without modification', 'Interpretation', 'Access source', 'Information request within document', 'SERP without modification', 'Scanning document with modification', 'Information request within document', 'END'] 0.02702702702702703
# ('bTabgmcTc3Tacda>', 1)
# ['Within-Document search result', 'Access source', 'Information request within document', 'Within-Document search result', 'Relevance judgement', 'Information request', 'SERP without modification', 'Access source', 'SERP without modification', 'Interpretation', 'Access source', 'Information request within document', 'SERP without modification', 'Scanning document with modification', 'Information request within document', 'END'] 0.02702702702702703
# ('<zGNc3D$37c3T$l7PXs43mG7cTXfYab3mjpGlGNcTfabafmGmGNjNG7cT$7fabtNa', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Interpretation', 'Info about document', 'Source information', 'Interpretation', 'Confirms', 'SERP without modification', 'Interpretation', 'Access source', 'Source information', 'Rejects', 'Confirms', 'Information request within SERP', 'Wayfinding', 'Next', 'SERP with modification', 'Interpretation', 'Information request', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Wayfinding', 'Scanning document without modification', 'Interpretation of photos', 'Information request within document', 'Within-Document search result', 'Interpretation', 'Information request', 'Asks to repeat', 'Query repeat', 'Query refinement offer', 'Rejects', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Access source', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Information request within document', 'Scanning document without modification', 'Information request', 'Query refinement offer', 'Information request', 'Query refinement offer', 'Intent clarification', 'Asks to repeat', 'Intent clarification', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Source information', 'Confirms', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Asking what they are looking for', 'Intent clarification', 'Information request within document'] 0.02702702702702703
# ('<zGNc3D$37c3T$l7PXs43mG7cTXfYab3mj', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Interpretation', 'Info about document', 'Source information', 'Interpretation', 'Confirms', 'SERP without modification', 'Interpretation', 'Access source', 'Source information', 'Rejects', 'Confirms', 'Information request within SERP', 'Wayfinding', 'Next', 'SERP with modification', 'Interpretation', 'Information request', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Wayfinding', 'Scanning document without modification', 'Interpretation of photos', 'Information request within document', 'Within-Document search result', 'Interpretation', 'Information request', 'Asks to repeat'] 0.02702702702702703
# ('<zGNc3D$37c3T$l7', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Interpretation', 'Info about document', 'Source information', 'Interpretation', 'Confirms', 'SERP without modification', 'Interpretation', 'Access source', 'Source information', 'Rejects', 'Confirms'] 0.02702702702702703
# ('<zGNc3D$37c3T$l7PXs43mG7cTXfYab3mjpG', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Interpretation', 'Info about document', 'Source information', 'Interpretation', 'Confirms', 'SERP without modification', 'Interpretation', 'Access source', 'Source information', 'Rejects', 'Confirms', 'Information request within SERP', 'Wayfinding', 'Next', 'SERP with modification', 'Interpretation', 'Information request', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Wayfinding', 'Scanning document without modification', 'Interpretation of photos', 'Information request within document', 'Within-Document search result', 'Interpretation', 'Information request', 'Asks to repeat', 'Query repeat', 'Query refinement offer'] 0.02702702702702703
# ('<zGNc3D$37c3T$', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Interpretation', 'Info about document', 'Source information', 'Interpretation', 'Confirms', 'SERP without modification', 'Interpretation', 'Access source', 'Source information'] 0.02702702702702703
# ('<zGNc3D$37c3T$l7PXs43mG7cTXfYab3mjpGlGNcTfabaf', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Interpretation', 'Info about document', 'Source information', 'Interpretation', 'Confirms', 'SERP without modification', 'Interpretation', 'Access source', 'Source information', 'Rejects', 'Confirms', 'Information request within SERP', 'Wayfinding', 'Next', 'SERP with modification', 'Interpretation', 'Information request', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Wayfinding', 'Scanning document without modification', 'Interpretation of photos', 'Information request within document', 'Within-Document search result', 'Interpretation', 'Information request', 'Asks to repeat', 'Query repeat', 'Query refinement offer', 'Rejects', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Access source', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Information request within document', 'Scanning document without modification'] 0.02702702702702703
# ('fYab3mjpGlGNcTfabafmGmGNjNG7cT$7fabtNa7mj7%c&P">', 1)
# ['Scanning document without modification', 'Interpretation of photos', 'Information request within document', 'Within-Document search result', 'Interpretation', 'Information request', 'Asks to repeat', 'Query repeat', 'Query refinement offer', 'Rejects', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Access source', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Information request within document', 'Scanning document without modification', 'Information request', 'Query refinement offer', 'Information request', 'Query refinement offer', 'Intent clarification', 'Asks to repeat', 'Intent clarification', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Source information', 'Confirms', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Asking what they are looking for', 'Intent clarification', 'Information request within document', 'Confirms', 'Information request', 'Asks to repeat', 'Confirms', 'Previously seen results', 'SERP without modification', 'Interpretation biased towards information request or clarification given by the User', 'Information request within SERP', 'Feedback on what is happening', 'END'] 0.02702702702702703
# ('XfYab3mjpGlGNcTfabafmGmGNjNG7cT$7fabtNa7mj7%c&P">', 1)
# ['Wayfinding', 'Scanning document without modification', 'Interpretation of photos', 'Information request within document', 'Within-Document search result', 'Interpretation', 'Information request', 'Asks to repeat', 'Query repeat', 'Query refinement offer', 'Rejects', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Access source', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Information request within document', 'Scanning document without modification', 'Information request', 'Query refinement offer', 'Information request', 'Query refinement offer', 'Intent clarification', 'Asks to repeat', 'Intent clarification', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Source information', 'Confirms', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Asking what they are looking for', 'Intent clarification', 'Information request within document', 'Confirms', 'Information request', 'Asks to repeat', 'Confirms', 'Previously seen results', 'SERP without modification', 'Interpretation biased towards information request or clarification given by the User', 'Information request within SERP', 'Feedback on what is happening', 'END'] 0.02702702702702703
# ('$l7PXs43mG7cTXfYab3mjpGlGNcTfabafmGmGNjNG7cT$7fabtNa7mj7%c&P">', 1)
# ['Source information', 'Rejects', 'Confirms', 'Information request within SERP', 'Wayfinding', 'Next', 'SERP with modification', 'Interpretation', 'Information request', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Wayfinding', 'Scanning document without modification', 'Interpretation of photos', 'Information request within document', 'Within-Document search result', 'Interpretation', 'Information request', 'Asks to repeat', 'Query repeat', 'Query refinement offer', 'Rejects', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Access source', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Information request within document', 'Scanning document without modification', 'Information request', 'Query refinement offer', 'Information request', 'Query refinement offer', 'Intent clarification', 'Asks to repeat', 'Intent clarification', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Source information', 'Confirms', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Asking what they are looking for', 'Intent clarification', 'Information request within document', 'Confirms', 'Information request', 'Asks to repeat', 'Confirms', 'Previously seen results', 'SERP without modification', 'Interpretation biased towards information request or clarification given by the User', 'Information request within SERP', 'Feedback on what is happening', 'END'] 0.02702702702702703
# ('<zGNc3D$37c3T$l7PXs43mG', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Interpretation', 'Info about document', 'Source information', 'Interpretation', 'Confirms', 'SERP without modification', 'Interpretation', 'Access source', 'Source information', 'Rejects', 'Confirms', 'Information request within SERP', 'Wayfinding', 'Next', 'SERP with modification', 'Interpretation', 'Information request', 'Query refinement offer'] 0.02702702702702703
# ('T$l7PXs43mG7cTXfYab3mjpGlGNcTfabafmGmGNjNG7cT$7fabtNa7mj7%c&P">', 1)
# ['Access source', 'Source information', 'Rejects', 'Confirms', 'Information request within SERP', 'Wayfinding', 'Next', 'SERP with modification', 'Interpretation', 'Information request', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Wayfinding', 'Scanning document without modification', 'Interpretation of photos', 'Information request within document', 'Within-Document search result', 'Interpretation', 'Information request', 'Asks to repeat', 'Query repeat', 'Query refinement offer', 'Rejects', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Access source', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Information request within document', 'Scanning document without modification', 'Information request', 'Query refinement offer', 'Information request', 'Query refinement offer', 'Intent clarification', 'Asks to repeat', 'Intent clarification', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Source information', 'Confirms', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Asking what they are looking for', 'Intent clarification', 'Information request within document', 'Confirms', 'Information request', 'Asks to repeat', 'Confirms', 'Previously seen results', 'SERP without modification', 'Interpretation biased towards information request or clarification given by the User', 'Information request within SERP', 'Feedback on what is happening', 'END'] 0.02702702702702703
# ('<zGNc3D$37c3T$l7PXs43mG7cTXfYab3mjpGlGNcTfabafmG', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Interpretation', 'Info about document', 'Source information', 'Interpretation', 'Confirms', 'SERP without modification', 'Interpretation', 'Access source', 'Source information', 'Rejects', 'Confirms', 'Information request within SERP', 'Wayfinding', 'Next', 'SERP with modification', 'Interpretation', 'Information request', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Wayfinding', 'Scanning document without modification', 'Interpretation of photos', 'Information request within document', 'Within-Document search result', 'Interpretation', 'Information request', 'Asks to repeat', 'Query repeat', 'Query refinement offer', 'Rejects', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Access source', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Information request within document', 'Scanning document without modification', 'Information request', 'Query refinement offer'] 0.02702702702702703
# ('mGNjNG7cT$7fabtNa7mj7%c&P">', 1)
# ['Information request', 'Query refinement offer', 'Intent clarification', 'Asks to repeat', 'Intent clarification', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Source information', 'Confirms', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Asking what they are looking for', 'Intent clarification', 'Information request within document', 'Confirms', 'Information request', 'Asks to repeat', 'Confirms', 'Previously seen results', 'SERP without modification', 'Interpretation biased towards information request or clarification given by the User', 'Information request within SERP', 'Feedback on what is happening', 'END'] 0.02702702702702703
# ('<zGNc3D$37c3T$l7PXs43mG7cTXfYab3mjpGlGNcTfaba', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Interpretation', 'Info about document', 'Source information', 'Interpretation', 'Confirms', 'SERP without modification', 'Interpretation', 'Access source', 'Source information', 'Rejects', 'Confirms', 'Information request within SERP', 'Wayfinding', 'Next', 'SERP with modification', 'Interpretation', 'Information request', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Wayfinding', 'Scanning document without modification', 'Interpretation of photos', 'Information request within document', 'Within-Document search result', 'Interpretation', 'Information request', 'Asks to repeat', 'Query repeat', 'Query refinement offer', 'Rejects', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Access source', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Information request within document'] 0.02702702702702703
# ('&P">', 1)
# ['Interpretation biased towards information request or clarification given by the User', 'Information request within SERP', 'Feedback on what is happening', 'END'] 0.02702702702702703
# ('D$37c3T$l7PXs43mG7cTXfYab3mjpGlGNcTfabafmGmGNjNG7cT$7fabtNa7mj7%c&P">', 1)
# ['Info about document', 'Source information', 'Interpretation', 'Confirms', 'SERP without modification', 'Interpretation', 'Access source', 'Source information', 'Rejects', 'Confirms', 'Information request within SERP', 'Wayfinding', 'Next', 'SERP with modification', 'Interpretation', 'Information request', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Wayfinding', 'Scanning document without modification', 'Interpretation of photos', 'Information request within document', 'Within-Document search result', 'Interpretation', 'Information request', 'Asks to repeat', 'Query repeat', 'Query refinement offer', 'Rejects', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Access source', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Information request within document', 'Scanning document without modification', 'Information request', 'Query refinement offer', 'Information request', 'Query refinement offer', 'Intent clarification', 'Asks to repeat', 'Intent clarification', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Source information', 'Confirms', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Asking what they are looking for', 'Intent clarification', 'Information request within document', 'Confirms', 'Information request', 'Asks to repeat', 'Confirms', 'Previously seen results', 'SERP without modification', 'Interpretation biased towards information request or clarification given by the User', 'Information request within SERP', 'Feedback on what is happening', 'END'] 0.02702702702702703
# ('c3D$37c3T$l7PXs43mG7cTXfYab3mjpGlGNcTfabafmGmGNjNG7cT$7fabtNa7mj7%c&P">', 1)
# ['SERP without modification', 'Interpretation', 'Info about document', 'Source information', 'Interpretation', 'Confirms', 'SERP without modification', 'Interpretation', 'Access source', 'Source information', 'Rejects', 'Confirms', 'Information request within SERP', 'Wayfinding', 'Next', 'SERP with modification', 'Interpretation', 'Information request', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Wayfinding', 'Scanning document without modification', 'Interpretation of photos', 'Information request within document', 'Within-Document search result', 'Interpretation', 'Information request', 'Asks to repeat', 'Query repeat', 'Query refinement offer', 'Rejects', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Access source', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Information request within document', 'Scanning document without modification', 'Information request', 'Query refinement offer', 'Information request', 'Query refinement offer', 'Intent clarification', 'Asks to repeat', 'Intent clarification', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Source information', 'Confirms', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Asking what they are looking for', 'Intent clarification', 'Information request within document', 'Confirms', 'Information request', 'Asks to repeat', 'Confirms', 'Previously seen results', 'SERP without modification', 'Interpretation biased towards information request or clarification given by the User', 'Information request within SERP', 'Feedback on what is happening', 'END'] 0.02702702702702703
# ('<zGNc3D$37', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Interpretation', 'Info about document', 'Source information', 'Interpretation', 'Confirms'] 0.02702702702702703
# ('<zGNc3D$37c3T$l7PXs43mG7cTXfYab3mjpGlGNcTfabafmGmGNjNG7cT$7fa', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Interpretation', 'Info about document', 'Source information', 'Interpretation', 'Confirms', 'SERP without modification', 'Interpretation', 'Access source', 'Source information', 'Rejects', 'Confirms', 'Information request within SERP', 'Wayfinding', 'Next', 'SERP with modification', 'Interpretation', 'Information request', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Wayfinding', 'Scanning document without modification', 'Interpretation of photos', 'Information request within document', 'Within-Document search result', 'Interpretation', 'Information request', 'Asks to repeat', 'Query repeat', 'Query refinement offer', 'Rejects', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Access source', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Information request within document', 'Scanning document without modification', 'Information request', 'Query refinement offer', 'Information request', 'Query refinement offer', 'Intent clarification', 'Asks to repeat', 'Intent clarification', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Source information', 'Confirms', 'Scanning document without modification', 'Information request within document'] 0.02702702702702703
# ('<zGNc3D$37c3T$l7PXs43mG7cTXfYab3mjpGlGNcTfabafmGmGNjNG7cT$7fabtN', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Interpretation', 'Info about document', 'Source information', 'Interpretation', 'Confirms', 'SERP without modification', 'Interpretation', 'Access source', 'Source information', 'Rejects', 'Confirms', 'Information request within SERP', 'Wayfinding', 'Next', 'SERP with modification', 'Interpretation', 'Information request', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Wayfinding', 'Scanning document without modification', 'Interpretation of photos', 'Information request within document', 'Within-Document search result', 'Interpretation', 'Information request', 'Asks to repeat', 'Query repeat', 'Query refinement offer', 'Rejects', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Access source', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Information request within document', 'Scanning document without modification', 'Information request', 'Query refinement offer', 'Information request', 'Query refinement offer', 'Intent clarification', 'Asks to repeat', 'Intent clarification', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Source information', 'Confirms', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Asking what they are looking for', 'Intent clarification'] 0.02702702702702703
# ('btNa7mj7%c&P">', 1)
# ['Within-Document search result', 'Asking what they are looking for', 'Intent clarification', 'Information request within document', 'Confirms', 'Information request', 'Asks to repeat', 'Confirms', 'Previously seen results', 'SERP without modification', 'Interpretation biased towards information request or clarification given by the User', 'Information request within SERP', 'Feedback on what is happening', 'END'] 0.02702702702702703
# ('jpGlGNcTfabafmGmGNjNG7cT$7fabtNa7mj7%c&P">', 1)
# ['Asks to repeat', 'Query repeat', 'Query refinement offer', 'Rejects', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Access source', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Information request within document', 'Scanning document without modification', 'Information request', 'Query refinement offer', 'Information request', 'Query refinement offer', 'Intent clarification', 'Asks to repeat', 'Intent clarification', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Source information', 'Confirms', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Asking what they are looking for', 'Intent clarification', 'Information request within document', 'Confirms', 'Information request', 'Asks to repeat', 'Confirms', 'Previously seen results', 'SERP without modification', 'Interpretation biased towards information request or clarification given by the User', 'Information request within SERP', 'Feedback on what is happening', 'END'] 0.02702702702702703
# ('<zGNc3D$37c3T$l7PXs43mG7cTXfYab3mjpGlGNcTfabafmGmGNjNG7cT$7fabtNa7mj7%', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Interpretation', 'Info about document', 'Source information', 'Interpretation', 'Confirms', 'SERP without modification', 'Interpretation', 'Access source', 'Source information', 'Rejects', 'Confirms', 'Information request within SERP', 'Wayfinding', 'Next', 'SERP with modification', 'Interpretation', 'Information request', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Wayfinding', 'Scanning document without modification', 'Interpretation of photos', 'Information request within document', 'Within-Document search result', 'Interpretation', 'Information request', 'Asks to repeat', 'Query repeat', 'Query refinement offer', 'Rejects', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Access source', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Information request within document', 'Scanning document without modification', 'Information request', 'Query refinement offer', 'Information request', 'Query refinement offer', 'Intent clarification', 'Asks to repeat', 'Intent clarification', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Source information', 'Confirms', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Asking what they are looking for', 'Intent clarification', 'Information request within document', 'Confirms', 'Information request', 'Asks to repeat', 'Confirms', 'Previously seen results'] 0.02702702702702703
# ('<zGNc3D$37c3T$l7PXs43mG7cTXfYab3m', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Interpretation', 'Info about document', 'Source information', 'Interpretation', 'Confirms', 'SERP without modification', 'Interpretation', 'Access source', 'Source information', 'Rejects', 'Confirms', 'Information request within SERP', 'Wayfinding', 'Next', 'SERP with modification', 'Interpretation', 'Information request', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Wayfinding', 'Scanning document without modification', 'Interpretation of photos', 'Information request within document', 'Within-Document search result', 'Interpretation', 'Information request'] 0.02702702702702703
# ('<zGNc3D$37c3T$l7PX', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Interpretation', 'Info about document', 'Source information', 'Interpretation', 'Confirms', 'SERP without modification', 'Interpretation', 'Access source', 'Source information', 'Rejects', 'Confirms', 'Information request within SERP', 'Wayfinding'] 0.02702702702702703
# ('<zGNc3D$37c3T$l7PXs43mG7cTXfYab3mjpGlGNcTfabafmGmGNjNG7cT$7fabt', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Interpretation', 'Info about document', 'Source information', 'Interpretation', 'Confirms', 'SERP without modification', 'Interpretation', 'Access source', 'Source information', 'Rejects', 'Confirms', 'Information request within SERP', 'Wayfinding', 'Next', 'SERP with modification', 'Interpretation', 'Information request', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Wayfinding', 'Scanning document without modification', 'Interpretation of photos', 'Information request within document', 'Within-Document search result', 'Interpretation', 'Information request', 'Asks to repeat', 'Query repeat', 'Query refinement offer', 'Rejects', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Access source', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Information request within document', 'Scanning document without modification', 'Information request', 'Query refinement offer', 'Information request', 'Query refinement offer', 'Intent clarification', 'Asks to repeat', 'Intent clarification', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Source information', 'Confirms', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Asking what they are looking for'] 0.02702702702702703
# ('7%c&P">', 1)
# ['Confirms', 'Previously seen results', 'SERP without modification', 'Interpretation biased towards information request or clarification given by the User', 'Information request within SERP', 'Feedback on what is happening', 'END'] 0.02702702702702703
# ('jNG7cT$7fabtNa7mj7%c&P">', 1)
# ['Asks to repeat', 'Intent clarification', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Source information', 'Confirms', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Asking what they are looking for', 'Intent clarification', 'Information request within document', 'Confirms', 'Information request', 'Asks to repeat', 'Confirms', 'Previously seen results', 'SERP without modification', 'Interpretation biased towards information request or clarification given by the User', 'Information request within SERP', 'Feedback on what is happening', 'END'] 0.02702702702702703
# ('<zGNc3D$37c3T$l7PXs43mG7cTXfYab3mjpGlGNcTfabafmGmGN', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Interpretation', 'Info about document', 'Source information', 'Interpretation', 'Confirms', 'SERP without modification', 'Interpretation', 'Access source', 'Source information', 'Rejects', 'Confirms', 'Information request within SERP', 'Wayfinding', 'Next', 'SERP with modification', 'Interpretation', 'Information request', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Wayfinding', 'Scanning document without modification', 'Interpretation of photos', 'Information request within document', 'Within-Document search result', 'Interpretation', 'Information request', 'Asks to repeat', 'Query repeat', 'Query refinement offer', 'Rejects', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Access source', 'Scanning document without modification', 'Information request within document', 'Within-Document search result', 'Information request within document', 'Scanning document without modification', 'Information request', 'Query refinement offer', 'Information request', 'Query refinement offer', 'Intent clarification'] 0.02702702702702703
# ('<zGNc3D$37c3T$l7PXs43mG7cTXfYab', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Interpretation', 'Info about document', 'Source information', 'Interpretation', 'Confirms', 'SERP without modification', 'Interpretation', 'Access source', 'Source information', 'Rejects', 'Confirms', 'Information request within SERP', 'Wayfinding', 'Next', 'SERP with modification', 'Interpretation', 'Information request', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Access source', 'Wayfinding', 'Scanning document without modification', 'Interpretation of photos', 'Information request within document', 'Within-Document search result'] 0.02702702702702703
# ('<zGNc3', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Interpretation'] 0.02702702702702703
# ('zGNc3D$37c3T$l7PXs43mG7cTXfYab3mjpGlGNcTfabafmGmGNjNG7cT$7fabtNa7mj7%c&P">', 1)
# ...
# ('zjpG7cGlmkPEcvHvKjGvdkl7mfmHNGlmHNjp6f7fCabmj>', 1)
# ['Initial information request', 'Asks to repeat', 'Query repeat', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Query refinement offer', 'Rejects', 'Information request', 'Enquiry for further information', 'Information request within SERP', 'Repeats the query back', 'SERP without modification', 'Automated repetitive search', 'Query rephrase', 'Automated repetitive search', 'Repeats', 'Asks to repeat', 'Query refinement offer', 'Automated repetitive search', 'Scanning document with modification', 'Enquiry for further information', 'Rejects', 'Confirms', 'Information request', 'Scanning document without modification', 'Information request', 'Query rephrase', 'Intent clarification', 'Query refinement offer', 'Rejects', 'Information request', 'Query rephrase', 'Intent clarification', 'Asks to repeat', 'Query repeat', 'Results?', 'Scanning document without modification', 'Confirms', 'Scanning document without modification', 'Performance feedback', 'Information request within document', 'Within-Document search result', 'Information request', 'Asks to repeat', 'END'] 0.02702702702702703
# ('<zjpG7cGlmkPEcvHvKjGvdkl7mfmHNG', 1)
# ['START', 'Initial information request', 'Asks to repeat', 'Query repeat', 'Query refinement offer', 'Confirms', 'SERP without modification', 'Query refinement offer', 'Rejects', 'Information request', 'Enquiry for further information', 'Information request within SERP', 'Repeats the query back', 'SERP without modification', 'Automated repetitive search', 'Query rephrase', 'Automated repetitive search', 'Repeats', 'Asks to repeat', 'Query refinement offer', 'Automated repetitive search', 'Scanning document with modification', 'Enquiry for further information', 'Rejects', 'Confirms', 'Information request', 'Scanning document without modification', 'Information request', 'Query rephrase', 'Intent clarification', 'Query refinement offer'] 0.02702702702702703
# ('zGNcs4mK7"6dm4Njpdmfm2>', 1)
# ['Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Next', 'SERP with modification', 'Information request', 'Repeats', 'Confirms', 'Feedback on what is happening', 'Results?', 'Scanning document with modification', 'Information request', 'SERP with modification', 'Intent clarification', 'Asks to repeat', 'Query repeat', 'Scanning document with modification', 'Information request', 'Scanning document without modification', 'Information request', 'Enough information', 'END'] 0.02702702702702703
# ('<zGNcs4mK7"6', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Next', 'SERP with modification', 'Information request', 'Repeats', 'Confirms', 'Feedback on what is happening', 'Results?'] 0.02702702702702703
# ('m4Njpdmfm2>', 1)
# ['Information request', 'SERP with modification', 'Intent clarification', 'Asks to repeat', 'Query repeat', 'Scanning document with modification', 'Information request', 'Scanning document without modification', 'Information request', 'Enough information', 'END'] 0.02702702702702703
# ('<zGNcs4mK7"', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Next', 'SERP with modification', 'Information request', 'Repeats', 'Confirms', 'Feedback on what is happening'] 0.02702702702702703
# ('"6dm4Njpdmfm2>', 1)
# ['Feedback on what is happening', 'Results?', 'Scanning document with modification', 'Information request', 'SERP with modification', 'Intent clarification', 'Asks to repeat', 'Query repeat', 'Scanning document with modification', 'Information request', 'Scanning document without modification', 'Information request', 'Enough information', 'END'] 0.02702702702702703
# ('<zGNcs4m', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Next', 'SERP with modification', 'Information request'] 0.02702702702702703
# ('dmfm2>', 1)
# ['Scanning document with modification', 'Information request', 'Scanning document without modification', 'Information request', 'Enough information', 'END'] 0.02702702702702703
# ('mfm2>', 1)
# ['Information request', 'Scanning document without modification', 'Information request', 'Enough information', 'END'] 0.02702702702702703
# ('Njpdmfm2>', 1)
# ['Intent clarification', 'Asks to repeat', 'Query repeat', 'Scanning document with modification', 'Information request', 'Scanning document without modification', 'Information request', 'Enough information', 'END'] 0.02702702702702703
# ('<zGNcs4mK7"6dm4Njpd', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Next', 'SERP with modification', 'Information request', 'Repeats', 'Confirms', 'Feedback on what is happening', 'Results?', 'Scanning document with modification', 'Information request', 'SERP with modification', 'Intent clarification', 'Asks to repeat', 'Query repeat', 'Scanning document with modification'] 0.02702702702702703
# ('<zGNcs4mK7"6d', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Next', 'SERP with modification', 'Information request', 'Repeats', 'Confirms', 'Feedback on what is happening', 'Results?', 'Scanning document with modification'] 0.02702702702702703
# ('<zGNcs4mK7"6dm4N', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Next', 'SERP with modification', 'Information request', 'Repeats', 'Confirms', 'Feedback on what is happening', 'Results?', 'Scanning document with modification', 'Information request', 'SERP with modification', 'Intent clarification'] 0.02702702702702703
# ('<zGNcs4mK7"6dm4Nj', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Next', 'SERP with modification', 'Information request', 'Repeats', 'Confirms', 'Feedback on what is happening', 'Results?', 'Scanning document with modification', 'Information request', 'SERP with modification', 'Intent clarification', 'Asks to repeat'] 0.02702702702702703
# ('m2>', 1)
# ['Information request', 'Enough information', 'END'] 0.02702702702702703
# ('<zGNcs4mK7"6dm4Njpdm', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Next', 'SERP with modification', 'Information request', 'Repeats', 'Confirms', 'Feedback on what is happening', 'Results?', 'Scanning document with modification', 'Information request', 'SERP with modification', 'Intent clarification', 'Asks to repeat', 'Query repeat', 'Scanning document with modification', 'Information request'] 0.02702702702702703
# ('cs4mK7"6dm4Njpdmfm2>', 1)
# ['SERP without modification', 'Next', 'SERP with modification', 'Information request', 'Repeats', 'Confirms', 'Feedback on what is happening', 'Results?', 'Scanning document with modification', 'Information request', 'SERP with modification', 'Intent clarification', 'Asks to repeat', 'Query repeat', 'Scanning document with modification', 'Information request', 'Scanning document without modification', 'Information request', 'Enough information', 'END'] 0.02702702702702703
# ('<zGNcs4mK7"6dm4Njpdmfm', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Next', 'SERP with modification', 'Information request', 'Repeats', 'Confirms', 'Feedback on what is happening', 'Results?', 'Scanning document with modification', 'Information request', 'SERP with modification', 'Intent clarification', 'Asks to repeat', 'Query repeat', 'Scanning document with modification', 'Information request', 'Scanning document without modification', 'Information request'] 0.02702702702702703
# ('Ncs4mK7"6dm4Njpdmfm2>', 1)
# ['Intent clarification', 'SERP without modification', 'Next', 'SERP with modification', 'Information request', 'Repeats', 'Confirms', 'Feedback on what is happening', 'Results?', 'Scanning document with modification', 'Information request', 'SERP with modification', 'Intent clarification', 'Asks to repeat', 'Query repeat', 'Scanning document with modification', 'Information request', 'Scanning document without modification', 'Information request', 'Enough information', 'END'] 0.02702702702702703
# ('GNcs4mK7"6dm4Njpdmfm2>', 1)
# ['Query refinement offer', 'Intent clarification', 'SERP without modification', 'Next', 'SERP with modification', 'Information request', 'Repeats', 'Confirms', 'Feedback on what is happening', 'Results?', 'Scanning document with modification', 'Information request', 'SERP with modification', 'Intent clarification', 'Asks to repeat', 'Query repeat', 'Scanning document with modification', 'Information request', 'Scanning document without modification', 'Information request', 'Enough information', 'END'] 0.02702702702702703
# ('s4mK7"6dm4Njpdmfm2>', 1)
# ['Next', 'SERP with modification', 'Information request', 'Repeats', 'Confirms', 'Feedback on what is happening', 'Results?', 'Scanning document with modification', 'Information request', 'SERP with modification', 'Intent clarification', 'Asks to repeat', 'Query repeat', 'Scanning document with modification', 'Information request', 'Scanning document without modification', 'Information request', 'Enough information', 'END'] 0.02702702702702703
# ('<zGNcs4', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Next', 'SERP with modification'] 0.02702702702702703
# ('<zGNcs', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Next'] 0.02702702702702703
# ('<zGNcs4mK7"6dm4Njp', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Next', 'SERP with modification', 'Information request', 'Repeats', 'Confirms', 'Feedback on what is happening', 'Results?', 'Scanning document with modification', 'Information request', 'SERP with modification', 'Intent clarification', 'Asks to repeat', 'Query repeat'] 0.02702702702702703
# ('dm4Njpdmfm2>', 1)
# ['Scanning document with modification', 'Information request', 'SERP with modification', 'Intent clarification', 'Asks to repeat', 'Query repeat', 'Scanning document with modification', 'Information request', 'Scanning document without modification', 'Information request', 'Enough information', 'END'] 0.02702702702702703
# ('<zGNcs4mK7"6dm4Njpdmfm2', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Next', 'SERP with modification', 'Information request', 'Repeats', 'Confirms', 'Feedback on what is happening', 'Results?', 'Scanning document with modification', 'Information request', 'SERP with modification', 'Intent clarification', 'Asks to repeat', 'Query repeat', 'Scanning document with modification', 'Information request', 'Scanning document without modification', 'Information request', 'Enough information'] 0.02702702702702703
# ('<zGNcs4mK7', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Next', 'SERP with modification', 'Information request', 'Repeats', 'Confirms'] 0.02702702702702703
# ('pdmfm2>', 1)
# ['Query repeat', 'Scanning document with modification', 'Information request', 'Scanning document without modification', 'Information request', 'Enough information', 'END'] 0.02702702702702703
# ('4Njpdmfm2>', 1)
# ['SERP with modification', 'Intent clarification', 'Asks to repeat', 'Query repeat', 'Scanning document with modification', 'Information request', 'Scanning document without modification', 'Information request', 'Enough information', 'END'] 0.02702702702702703
# ('K7"6dm4Njpdmfm2>', 1)
# ['Repeats', 'Confirms', 'Feedback on what is happening', 'Results?', 'Scanning document with modification', 'Information request', 'SERP with modification', 'Intent clarification', 'Asks to repeat', 'Query repeat', 'Scanning document with modification', 'Information request', 'Scanning document without modification', 'Information request', 'Enough information', 'END'] 0.02702702702702703
# ('mK7"6dm4Njpdmfm2>', 1)
# ['Information request', 'Repeats', 'Confirms', 'Feedback on what is happening', 'Results?', 'Scanning document with modification', 'Information request', 'SERP with modification', 'Intent clarification', 'Asks to repeat', 'Query repeat', 'Scanning document with modification', 'Information request', 'Scanning document without modification', 'Information request', 'Enough information', 'END'] 0.02702702702702703
# ('4mK7"6dm4Njpdmfm2>', 1)
# ['SERP with modification', 'Information request', 'Repeats', 'Confirms', 'Feedback on what is happening', 'Results?', 'Scanning document with modification', 'Information request', 'SERP with modification', 'Intent clarification', 'Asks to repeat', 'Query repeat', 'Scanning document with modification', 'Information request', 'Scanning document without modification', 'Information request', 'Enough information', 'END'] 0.02702702702702703
# ('<zGNcs4mK7"6dm', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Next', 'SERP with modification', 'Information request', 'Repeats', 'Confirms', 'Feedback on what is happening', 'Results?', 'Scanning document with modification', 'Information request'] 0.02702702702702703
# ('<zGNcs4mK7"6dm4', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Next', 'SERP with modification', 'Information request', 'Repeats', 'Confirms', 'Feedback on what is happening', 'Results?', 'Scanning document with modification', 'Information request', 'SERP with modification'] 0.02702702702702703
# ('jpdmfm2>', 1)
# ['Asks to repeat', 'Query repeat', 'Scanning document with modification', 'Information request', 'Scanning document without modification', 'Information request', 'Enough information', 'END'] 0.02702702702702703
# ('6dm4Njpdmfm2>', 1)
# ['Results?', 'Scanning document with modification', 'Information request', 'SERP with modification', 'Intent clarification', 'Asks to repeat', 'Query repeat', 'Scanning document with modification', 'Information request', 'Scanning document without modification', 'Information request', 'Enough information', 'END'] 0.02702702702702703
# ('fm2>', 1)
# ['Scanning document without modification', 'Information request', 'Enough information', 'END'] 0.02702702702702703
# ('7"6dm4Njpdmfm2>', 1)
# ['Confirms', 'Feedback on what is happening', 'Results?', 'Scanning document with modification', 'Information request', 'SERP with modification', 'Intent clarification', 'Asks to repeat', 'Query repeat', 'Scanning document with modification', 'Information request', 'Scanning document without modification', 'Information request', 'Enough information', 'END'] 0.02702702702702703
# ('<zGNcs4mK7"6dm4Njpdmf', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Next', 'SERP with modification', 'Information request', 'Repeats', 'Confirms', 'Feedback on what is happening', 'Results?', 'Scanning document with modification', 'Information request', 'SERP with modification', 'Intent clarification', 'Asks to repeat', 'Query repeat', 'Scanning document with modification', 'Information request', 'Scanning document without modification'] 0.02702702702702703
# ('<zGNcs4mK', 1)
# ['START', 'Initial information request', 'Query refinement offer', 'Intent clarification', 'SERP without modification', 'Next', 'SERP with modification', 'Information request', 'Repeats'] 0.02702702702702703

# %%
# search: find sample utterance by label pattern
pattern = "<zjpc"
cursor = collection.find({})
for doc in cursor:
    if pattern in doc['traces']['labels']:
        index = doc['traces']['labels'].find(pattern)
        _len = 0
        for turn in doc['turns']:
#             _len += len(turn['labels'])
#             if _len > index and _len <= index + len(pattern):
            print(turn['labels'])
            print("%s: %s"%(turn['role'], turn['text']))
        break
# Out:
# ['Initial information request']
# A_User: Please compare first word I'd like compare average international uhm and I'd like in inverted commas the words alcohol consumption... close inverted commas and then in open inverted commas per capita that's PER capita CAPITA close inverted commas... and that's if you could return the searches for that please
# ['Asks to repeat']
# B_Receiver: Sorry what, can you repeat that sentence
# ['Query repeat']
# A_User: Compare average open inverted commas oh sorry compare average international open inverted commas alcohol consumption close inverted commas open inverted commas per capita close inverted commas
# ['SERP without modification']
# B_Receiver: OK so the first result is Wikipedia and it's a list of countries by alcohol consumption per capita uhm and then the second source is also Wikipedia and that's uhm beer consumption per capita and then we have a pdf document from the World Health Organisation on global status report on alcohol and health uhm and we have a CNBC article uhm fifteen countries that consume the most alcohol uhm then it looks like an article from WSJ dot com which countries drink the most alcohol news dot com dot AU what countries drink the most amount of alcohol per capita and there is a website called statistica global per capita whiskey consumption uhm from two thousand and fourteen then a Wordpress site called epianalysis alcohol use around the globe new data trends and then the second to last one is US news dot com per capita USA and... yeah this one sort of seems to be very US focussed being high alcohol consumption in the US it sounds like a very US centric site and there is an other PDF from preventativehealth dot org dot AU key trends in alcohol consumption
# ['Access source']
# A_User: OK uhm... please open in a seperate tab the first one the Wikipedia alcohol consumption uhm per country per capita, the other one I would like open please is the last one you mentioned number 10 uhm the key trends in Australia in a seperate tab uhm and the fourth one you mentioned about uhm the fifteen countries that consume the most alcohol in a seperate tab, can we start with Wikipedia return response please?
# ['Scanning document with modification']
# B_Receiver: OK so it looks like it's covering World Health Organisation data from two thousand and ten uhm and the report was published in two thousand and fourteen uhm it has calculations used by people aged fifteen years and older uhm... and unrecorded consumption was calculated using empirical investigations and judgements, the total sum is of reported and unreported consumption uhm and then there are columns in here that break up consumption by beer, wine, spirits and other uhm other refers to other alcoholic beverages such as rice wine, sake, kumi kumi, kwete, mead and cider, and then there's a two thousand fifteen projection attached to this
# ['Information request within document']
# A_User: Does the data uhm illustrate per capita consumption... by country?
# ['Within-Document search result']
# B_Receiver: Uhm... I believe that that would be... the first column... OK this is the list of countries by alcohol consumption measured in equivalent litres of pure ethanol consumed per capita per year
# ['Performance feedback', 'Within-document command']
# A_User: Fantastic uhm please read out the top ten
# ['Within-Document search result']
# B_Receiver: Uhm Belarus, Moldova, Lithuania, Russia, Romania, Ukraine, Andorra, Hungary, Czech Republic
# ['Information request within document']
# A_User: Where is Australia in the list?
# ['Within-Document search result']
# B_Receiver: Number nineteen
# ['Information request within document']
# A_User: Number nineteen out of [inaudible segment]
# ['Within-Document search result']
# B_Receiver: Hundred and ninety
# ['Creating bigger picture', 'between-document navigation']
# A_User: Nineteen out of a hundred and ninety, ten percent of rater's rate uhm OK thank you uhm, I would like to move to one of the other open tabs please
# ['SERP with modification']
# B_Receiver: Yeah, so we have the PDF uhm and it is key trends in alcohol consumption uhm, it looks like it's part of a wider document uhm the document just got a heading with number two and two point one is alcohol consumption in Australia and other countries... there is a table on page two uhm which rates Australia as thirtieth and uhm consumption of alcohol consumption per capita out of a hundred and eighty countries and this is from a two thousand and eight World Health Organisation
# ['Access source (implicit)']
# A_User: With the other tab that is open, the Australian data
# ['Confirms']
# B_Receiver: Ah yeah
# ['Information request within document']
# A_User: Does that page have a breakdown of per capita alcohol consumption by state?
# ['Within-Document search result', 'Query refinement offer']
# B_Receiver: No... would you like me to search by state in Australia?
# ['Confirms']
# A_User: Yes please
# ['Query refinement offer']
# B_Receiver: So I am searching compare average Australian state inverted commas alcohol consumption inverted commas per capita so I've just changed international
# ['Confirms']
# A_User: Thank you
# ['SERP without modification']
# B_Receiver: Uhm so first result is that same Wikipedia by country, the second result is from Curtin University uhm and it is alcohol indicators executive summary uhm, and it's trends in alcohol-caused deaths and hospitalisation for all states and territories uhm, it does also seem in here uhm in the short summary it says the average Australian age fifteen and over consumed 9.32 litres pure ethanol in the financial year two thousand to two thousand and one so it may be very much in that date range, then the other one is from the Australian Bureau of Statistics and it is a two thousand thirteen two thousand fourteen and it is called apparent consumption of alcohol Australia uhm, and then the other one is from Bureau of Statistics Australian social trends nineteen ninety-five uhm and then we have another apparent consumption of alcohol Australia two thousand two two thousand thirteen from Bureau of Statistics uhm and then from MJA dot com dot AU per capita alcohol consumption in Australia will the real trend please stand up uhm and then Northern Territory tops statistics nationally for deaths from alcohol consumption that's an ABC article from two thousand fourteen uhm and then we've got how alcohol expenditure is distributed in Australia uhm, average alcohol expenditure in Australian states and territories uhm and then the fourth one is from AIHW dot gov dot AU and that looks from ninety-six ninety-seven results for uhm alcohol consumption in Australia I don't know if it gives you much in terms of state and then we've got another one from preventative health dot org dot AU uhm and it looks like table one shows Australia's level of per capita of alcohol consumption and it sort of has a lot of ellipsis and it doesn't give me a clear thing but it does point out that it has been cited by twelve other things on Google scholar

# %%
# analyse vocabulary usage
import string
from collections import Counter
import urllib.request
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer

wordnet_lemmatizer = WordNetLemmatizer()
englishStemmer = SnowballStemmer("english")

def load_word_list(lang='en'):
    url = 'https://raw.githubusercontent.com/stopwords-iso/stopwords-%s/master/stopwords-%s.txt' % (lang, lang)
    stopwords = urllib.request.urlopen(url).read().decode('UTF-8').split()
    print("Loaded %s stopwords, e.g. %s" % (lang, ", ".join(stopwords[:2])))
    return set(stopwords)


# load stopwords
en_stoplist = load_word_list('en')

cursor = collection.find({})
vocabulary = Counter()
for doc in cursor:
    _id = doc['_id']
    # record trace as the sequence of labels
    labels_trace = ''
    roles, sentiments = '', ''
#     print(doc['query'])
    for turn in doc['turns']:
        labels = turn['labels']
#         print(labels)
        # pre-processing: strip punctuation, lower-case, split on white spaces, remove stopwords, lemmatize with WordNet
        # or stem with Snowball stemmer
        words = turn['text'].translate(str.maketrans('', '', string.punctuation)).lower().split()
#         words = [englishStemmer.stem(word) for word in words if word not in en_stoplist]
        words = [wordnet_lemmatizer.lemmatize(word) for word in words if word not in en_stoplist]
        vocabulary.update(words)
#         print(words)
#     print(vocabulary.most_common(20))
#     break
print(vocabulary.most_common(20))
# Out:
# Loaded en stopwords, e.g. 'll, 'tis
# [('uhm', 567), ('yeah', 226), ('cinnamon', 94), ('security', 81), ('airport', 74), ('tyre', 74), ('alcohol', 71), ('job', 65), ('pause', 60), ('consumption', 59), ('article', 55), ('search', 54), ('india', 54), ('country', 47), ('river', 46), ('dot', 44), ('biscuit', 43), ('outsourcing', 41), ('water', 41), ('type', 39)]

# %%
# get collection specific counts for IDF metric

# %%
# annotate dialogues with words
cursor = collection.find({})

# interate over conversations to collect traces and utterance labels
traces = []
for doc in cursor:
    _id = doc['_id']
    # record trace as the sequence of labels
    labels_traces = ['', '', '']
    roles, sentiments = '', ''
    vocabulary_traces = ['', '']

#     print(doc['query'])
    for j, turn in enumerate(doc['turns']):
        labels = turn['labels']
        words = turn['text'].translate(str.maketrans('', '', string.punctuation)).lower().split()
#         words = [englishStemmer.stem(word) for word in words if word not in en_stoplist]
        words = [wordnet_lemmatizer.lemmatize(word) for word in words if word not in en_stoplist]
        vocabulary.update(words)
        print(vocabulary.most_common(20))
#         print(words)
#         print(words)
#         if len(labels) > 2:
#             print(j)
        if 'cinnamon' in words:
            vocabulary_traces[0] += 'c'
        else:
            vocabulary_traces[0] += 'O'
        if 'biscuit' in words:
            vocabulary_traces[1] += 'b'
        else:
            vocabulary_traces[1] += 'O'
            
#         break
        for i, label in enumerate(labels):
#             print(label)
            if i >= len(labels_traces):
                labels_traces.append('O'*(len(labels_traces[0])-1))  # pad to previous length
            labels_traces[i] += labels2ids[label]
        
        # pad remaining traces
        if len(labels) < len(labels_traces):
            for i in range(len(labels), len(labels_traces)):
                labels_traces[i] += 'O'
        roles += turn['role'][0]
        sentiments += turn['sentiment']
    # save in mongo
    for trace in labels_traces:
#         print(trace)
        assert len(trace) == len(roles)
    fingerprint = {'labels': labels_traces, 'roles': roles, 'sentiments': sentiments, 'semantics': vocabulary_traces}
    doc['traces'] = fingerprint
#     collection.update_one({'_id': _id}, {"$set": doc}, upsert=True)
    traces.append(fingerprint)
#     break
print("%d traces collected"%len(traces))
# print("Sample trace: %s"%traces[15])
print("\n")
for key, value in traces[0].items():
    if type(value) == list:
        for label_trace in value:
            print(label_trace)
    else:
        print(value)

# for label_trace in traces[15]['labels']:
#     print(label_trace)
#     print(len(label_trace))
#     print([ids2labels[label_id] for label_id in label_trace[-1]])
# print(utterances[0])
# Out:
# [('uhm', 567), ('yeah', 226), ('cinnamon', 95), ('security', 81), ('airport', 74), ('tyre', 74), ('alcohol', 71), ('job', 65), ('pause', 60), ('consumption', 59), ('article', 55), ('search', 54), ('india', 54), ('country', 49), ('river', 46), ('dot', 44), ('biscuit', 43), ('outsourcing', 41), ('water', 41), ('type', 39)]
# [('uhm', 568), ('yeah', 226), ('cinnamon', 95), ('security', 82), ('airport', 75), ('tyre', 74), ('alcohol', 71), ('job', 65), ('pause', 60), ('consumption', 59), ('article', 55), ('search', 54), ('india', 54), ('country', 49), ('river', 46), ('dot', 44), ('biscuit', 43), ('outsourcing', 41), ('water', 41), ('type', 40)]
# [('uhm', 568), ('yeah', 226), ('cinnamon', 95), ('security', 82), ('airport', 75), ('tyre', 74), ('alcohol', 71), ('job', 66), ('pause', 60), ('consumption', 59), ('india', 55), ('article', 55), ('search', 54), ('country', 49), ('river', 46), ('dot', 44), ('biscuit', 43), ('outsourcing', 41), ('water', 41), ('type', 40)]
# [('uhm', 569), ('yeah', 226), ('cinnamon', 95), ('security', 82), ('tyre', 78), ('airport', 75), ('alcohol', 71), ('job', 66), ('pause', 60), ('consumption', 59), ('india', 55), ('article', 55), ('search', 54), ('country', 49), ('river', 46), ('dot', 44), ('biscuit', 43), ('outsourcing', 41), ('water', 41), ('type', 40)]
# [('uhm', 570), ('yeah', 226), ('cinnamon', 95), ('security', 82), ('tyre', 78), ('airport', 75), ('alcohol', 72), ('job', 66), ('pause', 60), ('consumption', 60), ('search', 55), ('india', 55), ('article', 55), ('country', 49), ('river', 46), ('dot', 44), ('biscuit', 43), ('outsourcing', 41), ('water', 41), ('type', 40)]
# [('uhm', 570), ('yeah', 226), ('cinnamon', 95), ('security', 82), ('tyre', 78), ('airport', 75), ('alcohol', 72), ('job', 66), ('pause', 60), ('consumption', 60), ('search', 56), ('india', 55), ('article', 55), ('country', 49), ('river', 46), ('dot', 44), ('biscuit', 43), ('outsourcing', 41), ('water', 41), ('type', 40)]
# [('uhm', 570), ('yeah', 226), ('cinnamon', 95), ('security', 82), ('tyre', 78), ('airport', 75), ('alcohol', 72), ('job', 66), ('pause', 60), ('consumption', 60), ('search', 56), ('india', 55), ('article', 55), ('country', 49), ('river', 46), ('dot', 44), ('biscuit', 43), ('type', 41), ('outsourcing', 41), ('water', 41)]
# [('uhm', 571), ('yeah', 226), ('cinnamon', 96), ('security', 82), ('tyre', 78), ('airport', 75), ('alcohol', 72), ('job', 66), ('pause', 60), ('consumption', 60), ('search', 56), ('india', 55), ('article', 55), ('country', 49), ('river', 46), ('dot', 44), ('biscuit', 43), ('type', 42), ('outsourcing', 41), ('water', 41)]
# [('uhm', 576), ('yeah', 226), ('cinnamon', 96), ('security', 82), ('tyre', 78), ('airport', 75), ('alcohol', 75), ('job', 66), ('consumption', 63), ('pause', 60), ('search', 56), ('india', 55), ('article', 55), ('country', 52), ('river', 46), ('dot', 44), ('type', 43), ('biscuit', 43), ('outsourcing', 41), ('water', 41)]
# [('uhm', 576), ('yeah', 226), ('cinnamon', 96), ('security', 82), ('tyre', 78), ('airport', 75), ('alcohol', 75), ('job', 66), ('consumption', 63), ('pause', 60), ('search', 56), ('india', 55), ('article', 55), ('country', 52), ('river', 47), ('dot', 44), ('type', 43), ('biscuit', 43), ('outsourcing', 41), ('water', 41)]
# [('uhm', 576), ('yeah', 226), ('cinnamon', 96), ('security', 82), ('tyre', 78), ('airport', 75), ('alcohol', 75), ('job', 66), ('consumption', 63), ('pause', 60), ('search', 56), ('india', 55), ('article', 55), ('country', 52), ('river', 47), ('dot', 44), ('type', 43), ('biscuit', 43), ('water', 42), ('outsourcing', 41)]
# [('uhm', 576), ('yeah', 226), ('cinnamon', 96), ('security', 82), ('tyre', 78), ('airport', 75), ('alcohol', 75), ('job', 66), ('consumption', 63), ('pause', 60), ('search', 56), ('india', 55), ('article', 55), ('country', 52), ('river', 47), ('dot', 44), ('type', 43), ('biscuit', 43), ('water', 42), ('outsourcing', 41)]
# [('uhm', 576), ('yeah', 226), ('cinnamon', 96), ('security', 82), ('tyre', 78), ('airport', 75), ('alcohol', 75), ('job', 66), ('consumption', 63), ('pause', 60), ('search', 57), ('india', 55), ('article', 55), ('country', 52), ('river', 47), ('dot', 44), ('type', 43), ('biscuit', 43), ('outsourcing', 42), ('water', 42)]
# [('uhm', 576), ('yeah', 226), ('cinnamon', 96), ('security', 82), ('tyre', 78), ('airport', 75), ('alcohol', 75), ('job', 66), ('consumption', 63), ('pause', 60), ('search', 58), ('india', 55), ('article', 55), ('country', 52), ('river', 47), ('dot', 44), ('type', 43), ('biscuit', 43), ('outsourcing', 42), ('water', 42)]
# [('uhm', 577), ('yeah', 226), ('cinnamon', 96), ('security', 83), ('tyre', 78), ('airport', 76), ('alcohol', 75), ('job', 66), ('consumption', 63), ('pause', 60), ('search', 59), ('india', 55), ('article', 55), ('country', 52), ('river', 47), ('dot', 44), ('type', 43), ('biscuit', 43), ('outsourcing', 42), ('water', 42)]
# [('uhm', 577), ('yeah', 226), ('cinnamon', 96), ('security', 83), ('tyre', 78), ('airport', 76), ('alcohol', 75), ('job', 66), ('consumption', 63), ('pause', 60), ('search', 59), ('india', 55), ('article', 55), ('country', 52), ('river', 47), ('dot', 44), ('type', 43), ('biscuit', 43), ('outsourcing', 42), ('water', 42)]
# [('uhm', 577), ('yeah', 226), ('cinnamon', 96), ('security', 83), ('tyre', 78), ('airport', 76), ('alcohol', 75), ('job', 66), ('consumption', 63), ('pause', 60), ('search', 59), ('india', 55), ('article', 55), ('country', 52), ('river', 48), ('dot', 44), ('type', 43), ('biscuit', 43), ('outsourcing', 42), ('water', 42)]
# [('uhm', 577), ('yeah', 226), ('cinnamon', 96), ('security', 83), ('tyre', 78), ('airport', 76), ('alcohol', 76), ('job', 66), ('consumption', 64), ('pause', 60), ('search', 59), ('india', 55), ('article', 55), ('country', 52), ('river', 48), ('dot', 44), ('type', 43), ('biscuit', 43), ('outsourcing', 42), ('water', 42)]
# [('uhm', 577), ('yeah', 226), ('cinnamon', 98), ('security', 83), ('tyre', 78), ('airport', 76), ('alcohol', 76), ('job', 66), ('consumption', 64), ('pause', 60), ('search', 59), ('india', 55), ('article', 55), ('country', 54), ('river', 48), ('dot', 44), ('type', 43), ('biscuit', 43), ('outsourcing', 42), ('water', 42)]
# [('uhm', 578), ('yeah', 226), ('cinnamon', 98), ('security', 83), ('tyre', 78), ('airport', 76), ('alcohol', 76), ('job', 67), ('consumption', 64), ('pause', 60), ('search', 59), ('india', 56), ('article', 55), ('country', 54), ('river', 48), ('dot', 44), ('type', 43), ('biscuit', 43), ('outsourcing', 42), ('water', 42)]
# [('uhm', 578), ('yeah', 226), ('cinnamon', 98), ('security', 83), ('tyre', 78), ('airport', 76), ('alcohol', 76), ('job', 67), ('consumption', 64), ('search', 60), ('pause', 60), ('india', 56), ('article', 55), ('country', 54), ('river', 48), ('dot', 44), ('type', 43), ('biscuit', 43), ('outsourcing', 42), ('water', 42)]
# [('uhm', 578), ('yeah', 226), ('cinnamon', 98), ('security', 83), ('tyre', 78), ('airport', 76), ('alcohol', 76), ('job', 67), ('consumption', 64), ('search', 61), ('pause', 61), ('india', 56), ('article', 55), ('country', 54), ('river', 48), ('dot', 44), ('type', 43), ('biscuit', 43), ('water', 43), ('outsourcing', 42)]
# [('uhm', 579), ('yeah', 226), ('cinnamon', 98), ('security', 83), ('tyre', 80), ('airport', 76), ('alcohol', 76), ('job', 67), ('consumption', 64), ('search', 62), ('pause', 62), ('india', 56), ('article', 55), ('country', 54), ('river', 48), ('dot', 44), ('type', 43), ('biscuit', 43), ('water', 43), ('outsourcing', 42)]
# [('uhm', 579), ('yeah', 226), ('cinnamon', 98), ('security', 83), ('tyre', 80), ('airport', 76), ('alcohol', 76), ('job', 67), ('consumption', 64), ('search', 62), ('pause', 62), ('india', 56), ('article', 55), ('country', 54), ('river', 49), ('dot', 44), ('type', 43), ('biscuit', 43), ('water', 43), ('outsourcing', 42)]
# [('uhm', 579), ('yeah', 226), ('cinnamon', 98), ('security', 83), ('tyre', 81), ('airport', 76), ('alcohol', 76), ('job', 67), ('consumption', 64), ('search', 62), ('pause', 62), ('india', 56), ('article', 55), ('country', 54), ('river', 49), ('dot', 44), ('type', 43), ('biscuit', 43), ('water', 43), ('outsourcing', 42)]
# [('uhm', 580), ('yeah', 226), ('cinnamon', 98), ('security', 83), ('tyre', 81), ('airport', 76), ('alcohol', 76), ('job', 67), ('consumption', 64), ('pause', 63), ('search', 62), ('india', 56), ('article', 55), ('country', 54), ('river', 50), ('dot', 44), ('water', 44), ('type', 43), ('biscuit', 43), ('outsourcing', 42)]
# [('uhm', 580), ('yeah', 226), ('cinnamon', 99), ('security', 83), ('tyre', 81), ('airport', 76), ('alcohol', 76), ('job', 67), ('consumption', 64), ('pause', 63), ('search', 62), ('india', 56), ('article', 55), ('country', 54), ('river', 50), ('dot', 44), ('water', 44), ('type', 43), ('biscuit', 43), ('outsourcing', 42)]
# [('uhm', 580), ('yeah', 226), ('cinnamon', 99), ('security', 84), ('tyre', 81), ('airport', 77), ('alcohol', 76), ('job', 67), ('consumption', 64), ('pause', 63), ('search', 62), ('india', 56), ('article', 55), ('country', 54), ('river', 50), ('dot', 44), ('water', 44), ('type', 43), ('biscuit', 43), ('outsourcing', 42)]
# [('uhm', 580), ('yeah', 226), ('cinnamon', 99), ('security', 84), ('tyre', 81), ('airport', 77), ('alcohol', 76), ('job', 68), ('consumption', 64), ('pause', 63), ('search', 62), ('india', 57), ('article', 55), ('country', 54), ('river', 50), ('dot', 44), ('water', 44), ('type', 43), ('biscuit', 43), ('outsourcing', 42)]
# [('uhm', 581), ('yeah', 226), ('cinnamon', 99), ('security', 84), ('tyre', 83), ('airport', 77), ('alcohol', 76), ('job', 68), ('consumption', 64), ('pause', 63), ('search', 62), ('india', 57), ('article', 55), ('country', 54), ('river', 50), ('type', 44), ('dot', 44), ('water', 44), ('biscuit', 43), ('outsourcing', 42)]
# [('uhm', 582), ('yeah', 226), ('cinnamon', 99), ('security', 84), ('tyre', 83), ('airport', 77), ('alcohol', 77), ('job', 68), ('consumption', 65), ('pause', 63), ('search', 62), ('india', 57), ('article', 55), ('country', 54), ('river', 50), ('type', 44), ('dot', 44), ('water', 44), ('biscuit', 43), ('outsourcing', 42)]
# [('uhm', 582), ('yeah', 226), ('cinnamon', 99), ('security', 84), ('tyre', 83), ('airport', 77), ('alcohol', 77), ('job', 68), ('consumption', 65), ('pause', 63), ('search', 62), ('india', 57), ('article', 55), ('country', 54), ('river', 50), ('type', 45), ('dot', 44), ('water', 44), ('biscuit', 43), ('outsourcing', 42)]
# [('uhm', 582), ('yeah', 226), ('cinnamon', 99), ('security', 84), ('tyre', 83), ('airport', 77), ('alcohol', 77), ('job', 68), ('consumption', 65), ('pause', 63), ('search', 62), ('india', 57), ('article', 55), ('country', 54), ('river', 50), ('type', 45), ('dot', 44), ('water', 44), ('biscuit', 43), ('outsourcing', 42)]
# [('uhm', 588), ('yeah', 226), ('cinnamon', 102), ('security', 84), ('tyre', 83), ('airport', 77), ('alcohol', 77), ('job', 68), ('consumption', 65), ('search', 63), ('pause', 63), ('india', 57), ('article', 55), ('country', 54), ('river', 50), ('type', 45), ('biscuit', 45), ('dot', 44), ('water', 44), ('outsourcing', 42)]
# [('uhm', 589), ('yeah', 226), ('cinnamon', 102), ('security', 84), ('tyre', 83), ('alcohol', 78), ('airport', 77), ('job', 68), ('consumption', 66), ('search', 63), ('pause', 63), ('india', 57), ('country', 55), ('article', 55), ('river', 50), ('type', 45), ('biscuit', 45), ('dot', 44), ('water', 44), ('outsourcing', 42)]
# [('uhm', 589), ('yeah', 226), ('cinnamon', 102), ('security', 84), ('tyre', 83), ('alcohol', 78), ('airport', 77), ('job', 68), ('consumption', 66), ('search', 64), ('pause', 63), ('india', 57), ('country', 55), ('article', 55), ('river', 51), ('type', 45), ('biscuit', 45), ('dot', 44), ('water', 44), ('outsourcing', 42)]
# [('uhm', 589), ('yeah', 226), ('cinnamon', 102), ('security', 84), ('tyre', 83), ('alcohol', 78), ('airport', 77), ('job', 68), ('consumption', 66), ('search', 65), ('pause', 63), ('india', 57), ('country', 55), ('article', 55), ('river', 52), ('type', 45), ('biscuit', 45), ('dot', 44), ('water', 44), ('outsourcing', 42)]
# 37 traces collected
